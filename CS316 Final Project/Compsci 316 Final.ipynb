# %%
##Idea is to get all relavant departments because the API had a ton of noise that would make the program much slower
##and much more difficult to debug. I got the relavant departments by transcribing the availible ones on Dukehub.

##ME, OVS excluded because not on database, I do not know why ME is not because it is very common

courses_we_want = ["AAAS","ACCOUNTG","AEROSCI","AMES","AMI","AMXTIAN","ANESTH","ARABIC","ARTHIST","ARTS&SCI","ARTSVIS","ASEP"]
courses_we_want.extend(["BA","BCS","BES","BIOCHEM","BIOETHIC","BIOLOGY","BIOSTAT","BME","BRAINSOC","BSP"])
courses_we_want.extend(["CBB","CEE","CELLBIO","CESC","CHEM","CHILDPOL","CHINESE","CHURHST","CHURMIN","CLP","CLST","CMAC","CMB","COMMFAM","COMPSCI","CONTDIV","CONTENV","CONTNUR","CONTPPS","CPE","CROELE","CRP","CRS","CRSP","CTN","CULANTH","CVS"])
courses_we_want.extend(["DANCE","DECISION","DESCI","DMNISTRY","DOCST"])
courses_we_want.extend(["ECE","ECON","EDUC","EGR","EGRMGMT","EHD","ENERGY","ENGLISH","ENNGYEGR","ENRGYENV","ENVIRON","EOS","EPH","ETHICS","EVANTH"])
courses_we_want.extend(["FIELDEDU","FINANCE","FREETIME","FRENCH","FUQINTRD"])
courses_we_want.extend(["GATE","GENOME","GERMAN","GHS","GLHLTH","GREEK","GS","GSF"])
courses_we_want.extend(["HCVIS","HEBREW","HGP","HINDI","HISTORY","HISTREL","HISTTHEO","HLTHMGMT","HLTHSCI","HOUSECS","HUMANDEV"])
courses_we_want.extend(["I&E","ICS","IDS","IMMUNOL","INTERDIS","ISS","ITALIAN"])
courses_we_want.extend(["JEWISHST","JPN"])
courses_we_want.extend(["KOREAN"])
courses_we_want.extend(["LATAMER","LATIN","LAW","LINGUIST","LIT","LS","LSGS","LTS"])
courses_we_want.extend(["MANAGEMT","MARKETING","MAT","MATH","MEDHUM","MEDICINE","MEDPHY","MEDREN","MENG","MFAEDA","MGM","MGMTCOM","MGRECON","MIDIP","MILITSCI","MMCI","MMS","MOLCAN","MOLMED","MSIS","MSLS","MUSIC"])
courses_we_want.extend(["NAONOSCI","NAVALSCI","NCS","NEURO","NEUROBIO","NEUROSCI","NEUROSUR","NEWTEST","NSS","NURSING"])
courses_we_want.extend(["OBGYN","OLDTEST","OPERATNS","OPHTHAL","OPTECH","OPTRS","ORTHO"])
courses_we_want.extend(["PARISH","PASTCARE","PATHASST","PATHOL","PCLT","PEDS","PERSIAN","PHARM","PHIL","PHYASST","PHYSEDU","PHYSICS","PJMS","PMT","POLISH","POLSCI","PORTUGUE","PREACHING","PSP","PSY","PSYCHTRY","PT-D","PUBPOL"])
##none that start with Q
courses_we_want.extend(["RADIOL","RADONC","REG","RELIGION","RESEARCH","RIGHTS","ROMST","RROMP","RUSSIAN"])
courses_we_want.extend(["SBB","SCISOC","SES","SOCIOL","SPANISH","SPIRIT","STA","STDYAWAY","STRATEGY","SURGERY","SXL"])
courses_we_want.extend(["THEATRST","THESIS","TIBETAN","TURKISH"])
courses_we_want.extend(["UPE","UPGEN"])
courses_we_want.extend(["VMS"])
courses_we_want.extend(["WRITING","WXTIAN"])
courses_we_want.extend(["XTIANEDU","XTIANETH","XTIANPRC","XTIANTHE"])
##none that start with Y
##none that start with Z

# %%
import requests as rq
def get_all_subjects(): ##Get course departments and longer name for all departments from above. Used to be more useful
                        ##When did not have the above courses_we_want table. Was also full of edge case if statements
    all_courses = []
    ##found URL based on Duke API. 
    data = rq.get("https://streamer.oit.duke.edu/curriculum/list_of_values/fieldname/SUBJECT?access_token=f3849db401a3437f92241b5da3b98e1b").json()
    ##found path based on API as well
    classes = data["scc_lov_resp"]["lovs"]["lov"]["values"]["value"]
    for course in classes:
        if str(course["code"]) not in courses_we_want: ##It is a weird department
            continue
        all_courses.append([str(course["code"]),str(course["desc"])])
    return all_courses
complete_course_list = get_all_subjects()
# print complete_course_list
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-ad9223c20c08> in <module>()
#      12         all_courses.append([str(course["code"]),str(course["desc"])])
#      13     return all_courses
# ---> 14 complete_course_list = get_all_subjects()
#      15 # print complete_course_list
#
# <ipython-input-2-ad9223c20c08> in get_all_subjects()
#       4     all_courses = []
#       5     ##found URL based on Duke API.
# ----> 6     data = rq.get("https://streamer.oit.duke.edu/curriculum/list_of_values/fieldname/SUBJECT?access_token=f3849db401a3437f92241b5da3b98e1b").json()
#       7     ##found path based on API as well
#       8     classes = data["scc_lov_resp"]["lovs"]["lov"]["values"]["value"]
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/models.pyc in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/simplejson/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     516             parse_constant is None and object_pairs_hook is None
#     517             and not use_decimal and not kw):
# --> 518         return _default_decoder.decode(s)
#     519     if cls is None:
#     520         cls = JSONDecoder
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/simplejson/decoder.pyc in decode(self, s, _w, _PY3)
#     368         if _PY3 and isinstance(s, binary_type):
#     369             s = s.decode(self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#     372         if end != len(s):
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/simplejson/decoder.pyc in raw_decode(self, s, idx, _w, _PY3)
#     398             elif ord0 == 0xef and s[idx:idx + 3] == '\xef\xbb\xbf':
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# print complete_course_list[4]
token = "f3849db401a3437f92241b5da3b98e1b" ##my API token I got for this assignment
base_url = "https://streamer.oit.duke.edu/curriculum/courses/subject/"

def get_ids_and_numbers(Department): ##gets class number and also other portion to make it unique
    answer = []
    add_on = (Department[0] + " - " + Department[1]).replace(" ","%20") + "?" + "access_token=" + token
#     print base_url + add_on
    data = rq.get(base_url + add_on).json()
#print_json_tree(data["ssr_get_courses_resp"]["course_search_result"]["subjects"]["subject"])
#     print Department[0]
    if data["ssr_get_courses_resp"]["course_search_result"]["ssr_crs_gen_msg"] == "The Search has returned no results":
        return "skip" ##I return skip if the course cannot be found in the API
    if "ssr_get_courses_resp" not in data.keys():
        return "skip" ##This is an edge case for one bad data point
    courses = data["ssr_get_courses_resp"]["course_search_result"]["subjects"]["subject"]["course_summaries"]["course_summary"]
    ids_and_numbers = []
#     print len(courses)
    if type(courses) == list: ##it would be a dict otherwise and could be added to the list straight away
        for i in range(len(courses)): ##add all courses from that department to the list of courses
            course = courses[i]
            if "msg_txt" in course.keys():
                if course["msg_txt"] == "** available as of 2019-01-01":
                    continue ##This class has not started yet and nobody could thus be in this class ever
            to_append = [str(course["crse_id"]),str(course["crse_offer_nbr"])]
            answer.append(to_append)
    else:
        to_append = [str(courses["crse_id"]),str(courses["crse_offer_nbr"])]
        answer.append(to_append)

    return answer
ids_and_numbers = get_ids_and_numbers(complete_course_list[4])
# print ids_and_numbers
# Out:
# [['018029', '1'], ['019765', '1'], ['001873', '4'], ['024999', '2'], ['024426', '2'], ['021768', '1'], ['004558', '1'], ['021769', '1'], ['022108', '3'], ['023563', '1'], ['022989', '1'], ['003845', '3'], ['018102', '1'], ['025329', '1'], ['006321', '2'], ['019781', '2'], ['017078', '2'], ['022160', '2'], ['018715', '3'], ['021858', '1'], ['024152', '1'], ['021859', '1'], ['004565', '1'], ['012901', '1'], ['020269', '2'], ['017077', '6'], ['020222', '3'], ['020830', '1'], ['019110', '6'], ['019346', '7'], ['022593', '3'], ['024709', '3'], ['006322', '3'], ['023326', '3'], ['023920', '2'], ['023910', '2'], ['014341', '2'], ['023632', '2'], ['022997', '3'], ['020610', '2'], ['021369', '2'], ['021331', '2'], ['006320', '5'], ['013901', '2'], ['000040', '3'], ['024130', '2'], ['019451', '3'], ['019049', '2'], ['000028', '3'], ['016582', '3'], ['000029', '3'], ['016410', '3'], ['018481', '2'], ['016082', '2'], ['004492', '2'], ['016992', '3'], ['020119', '2'], ['022308', '2'], ['005278', '3'], ['009652', '4'], ['012958', '3'], ['019356', '6'], ['020782', '3'], ['021215', '3'], ['019055', '6'], ['000010', '7'], ['021303', '2'], ['023843', '1'], ['009310', '3'], ['025331', '5'], ['020517', '2'], ['006412', '2'], ['022133', '3'], ['025594', '6'], ['020567', '2'], ['022541', '3'], ['023929', '2'], ['017454', '1'], ['018442', '1'], ['004571', '1'], ['023901', '4'], ['006413', '1'], ['023655', '2'], ['004559', '3'], ['024200', '5'], ['013134', '3'], ['022309', '3'], ['003094', '3'], ['021370', '1'], ['020179', '2'], ['000638', '3'], ['024708', '5'], ['016771', '2'], ['023870', '2'], ['021128', '3'], ['022596', '3'], ['022872', '2'], ['004561', '2'], ['017075', '3'], ['015477', '1'], ['019432', '3'], ['016395', '3'], ['022331', '3'], ['022163', '3'], ['023016', '2'], ['008062', '2'], ['020227', '1'], ['020829', '3'], ['021119', '2'], ['021070', '3'], ['023237', '2'], ['023603', '2'], ['018104', '1'], ['022767', '4'], ['020113', '3'], ['022923', '2'], ['004562', '1'], ['022769', '3'], ['019112', '3'], ['023899', '2'], ['019651', '1'], ['020225', '1'], ['020226', '1'], ['021060', '2'], ['022452', '1'], ['024102', '3'], ['012996', '4'], ['024113', '4'], ['021783', '1'], ['013007', '2'], ['023275', '2'], ['025281', '3'], ['023912', '3'], ['025276', '3'], ['020788', '1'], ['018106', '1'], ['023931', '3'], ['023079', '1'], ['022250', '1'], ['004560', '1'], ['004567', '1'], ['019776', '3'], ['022582', '4'], ['024404', '2'], ['025656', '2'], ['020795', '4'], ['023324', '2'], ['024422', '1'], ['025004', '2'], ['024757', '2'], ['022581', '4'], ['018103', '1'], ['024365', '2'], ['025602', '5'], ['016424', '2'], ['025066', '3'], ['024679', '3'], ['021414', '1'], ['013920', '1'], ['020320', '1'], ['025031', '2'], ['015514', '1'], ['022584', '3'], ['025676', '3'], ['025132', '3'], ['022583', '5'], ['023940', '2'], ['024790', '2'], ['017811', '2'], ['022560', '2'], ['018229', '2'], ['021886', '3'], ['022899', '2'], ['023943', '2'], ['019368', '4'], ['020137', '2'], ['022193', '5'], ['018023', '2'], ['022186', '5'], ['000062', '2'], ['023805', '1'], ['023121', '1'], ['025131', '2'], ['018430', '4'], ['020484', '2'], ['020825', '2'], ['025666', '2'], ['021332', '5'], ['024182', '3'], ['023352', '1'], ['021845', '1'], ['019782', '1'], ['020671', '1'], ['025661', '1'], ['025662', '1'], ['025663', '1'], ['023556', '2'], ['025555', '3'], ['021181', '1'], ['025282', '2'], ['025076', '1']]

# %%
attribute_list = ["(ALP)","(CCI)","(CZ)","(EI)","(FL)","(NS)","(QS)","(SS)","(R)","(SEM)","(STS)","(W)"]
##the attribute list has () around the attributes because that is how they appear in the api
terms_offered = ["2012 Fall Term", "2013 Spring Term","2013 Fall Term","2014 Spring Term","2014 Fall Term","2015 Spring Term","2015 Fall Term","2016 Spring Term","2016 Fall Term","2017 Spring Term","2017 Fall Term","2018 Spring Term","2018 Fall Term","2019 Spring Term"]
##I chose to only focus on the spring and fall terms becaue I felt that was easiest. The API goes back to 2012 fall at 
##its earliest
def create_terms(terms_offered, start_number): ##method that creates terms to be the way the API has it. This was
    answer = []                                ##slightly more complicated than I thought it would be
    number = start_number - 30
    for i in range(len(terms_offered)):
        if i%2 != 0:
            number = number + 10
            answer.append(str(number) + " - " + terms_offered[i])
        else:
            number = number + 30
            answer.append(str(number) + " - " + terms_offered[i])
    return answer

all_terms = create_terms(terms_offered,1420) ##storing all terms in all_terms variable

# %%
url_section0 = "https://streamer.oit.duke.edu/curriculum/classes/strm/"
# 1670%20-%202019%20Spring%20Term/crse_id/000081/crse_offer_nbr/1/session_code/1/class_section/01?access_token=f3849db401a3437f92241b5da3b98e1b
def make_course(course_id,course_offer_number,time_period):
    course = []
    url_section1 = time_period.replace(" ","%20")
    url_section2 = "/crse_id/"
    url_section3 = course_id
    url_section4 = "/crse_offer_nbr/"
    url_section5 = course_offer_number
    url_section6 = "/session_code/1/class_section/01?access_token="
    url_full = url_section0 + url_section1 + url_section2 + url_section3 + url_section4 + url_section5 + url_section6 + token
#     print url_full
    data = rq.get(url_full).json()
#   if data["ssr_get_course_offering_resp"]["course_offering_result"]["ssr_crs_gen_msg"] == "***  This course has not been scheduled.  ***":
#         url = url_base
# #             print "exiting because course never offered"
#         continue
#     if "course_offering" not in data["ssr_get_course_offering_resp"]["course_offering_result"]:
#         url = url_base
# #             print "exiting because course offering never happened"
#         continue
    if "ssr_get_class_section_resp" not in data.keys(): ##edge case
        return []
    if data["ssr_get_class_section_resp"]["class_section_result"]["class_sections"] == data["ssr_get_class_section_resp"]["class_section_result"]["ssr_crs_gen_msg"]: 
        return [] ##edge case where nothing was there. This was the way I found to capture it but theres probs a better way
        
    class_section = data["ssr_get_class_section_resp"]["class_section_result"]["class_sections"]["ssr_class_section"]
    
    
    name = str(class_section["crse_id_lov_descr"])
    subject = str(class_section["subject"])
    course_number = str(class_section["catalog_nbr"])[1:]
    prereqs = str(class_section["ssr_requisite_long"])
    
        
    attributes = []
    if class_section["ssr_component"] == "SEM": ##I chose to abbreviate seminar as S not SEM
        attributes.append("S")
    
    class_meeting = class_section["class_meeting_patterns"]["class_meeting_pattern"]
    if len(class_meeting) < 5:
        class_meeting = class_meeting[0]
    meeting_times = str(class_meeting["ssr_mtg_sched_long"])
    meeting_location = str(class_meeting["ssr_mtg_loc_long"])
    instructor = str(class_meeting["ssr_instr_long"])
    

    for attribute in attribute_list:
        if class_section["enrollment_details"]["enrollment_information"]["class_attributes"]:
            if attribute in class_section["enrollment_details"]["enrollment_information"]["class_attributes"]:
                attributes.append(attribute[1:-1])
    
                                                                
    return [course_id,name,subject,course_number,time_period[7:],prereqs,meeting_times,meeting_location,instructor,attributes]
    ## I returned this because this is all the useful data that I would need from this specific API category. This 
    ## is the most important returned value
# print make_course(ids_and_numbers[0][0],ids_and_numbers[0][1],all_terms[0])

# %%
ids_and_numbers = []
for i in range((len(complete_course_list))):
    course_list = get_ids_and_numbers(complete_course_list[i])
    ids_and_numbers.extend(course_list)
    print len(ids_and_numbers)
# Out:
# 191
# 230
# 239
# 486
# 687
# 708
# 718
# 743
# 977
# 1004
# 1117
# 1118
# 1150
# 1169
# 1171
# 1198
# 1219
# 1442
# 1487
# 1600
# 1605
# 1606
# 1630
# 1737
# 1754
# 1756
# 1827
# 1838
# 1876
# 1922
# 1931
# 1947
# 2055
# 2078
# 2097
# 2115
# 2205
# 2207
# 2211
# 2215
# 2216
# 2235
# 2264
# 2265
# 2266
# 2270
# 2516
# 2517
# 2616
# 2655
# 2662
# 2805
# 2929
# 3216
# 3296
# 3330
# 3350
# 3369
# 3412
# 3644
# 3656
# 4070
# 4168
# 4169
# 4257
# 4341
# 4346
# 4396
# 4397
# 4508
# 4546
# 4556
# 4566
# 4677
# 4678
# 4869
# 4906
# 4943
# 5094
# 5103
# 5115
# 5116
# 5128
# 5577
# 5587
# 5611
# 5638
# 5664
# 5665
# 5671
# 5718
# 5998
# 6019
# 6031
# 6065
# 6190
# 6284
# 6350
# 6366
# 6377
# 6410
# 6457
# 6857
# 6939
# 7201
# 7205
# 7230
# 7249
# 7307
# 7315
# 7484
# 7485
# 7530
# 7595
# 7736
# 7740
# 7750
# 7777
# 7801
# 7829
# 7830
# 7847
# 7864
# 7887
# 7900
# 7905
# 7906
# 7907
# 8106
# 8121
# 8123
# 8131
# 8162
# 8270
# 8274
# 8358
# 8359
# 8596
# 8612
# 8689
# 8716
# 8720
# 8746
# 8749
# 8762
# 8825
# 8846
# 8872
# 8889
# 8890
# 8932
# 8940
# 8975
# 9119
# 9215
# 9304
# 9408
# 9451
# 9452
# 9469
# 9903
# 9934
# 9935
# 10161
# 10172
# 10217
# 10624
# 10634
# 10636
# 10648
# 10969
# 10970
# 11105
# 11185
# 11186
# 11356
# 11362
# 11411
# 11468
# 11622
# 11742
# 11747
# 11833
# 11842
# 11887
# 11926
# 11951
# 12077
# 12078
# 12088
# 12107
# 12112
# 12142
# 12465
# 12483
# 12509
# 12532
# 12564
# 12565
# 12658

# %%
for i in range(len(ids_and_numbers)):
    print i, ids_and_numbers[i]
# Out:
# 0 ['000064', '1']
# 1 ['000081', '1']
# 2 ['000082', '1']
# 3 ['022918', '2']
# 4 ['019142', '4']
# 5 ['017879', '2']
# 6 ['020070', '3']
# 7 ['020130', '2']
# 8 ['018580', '2']
# 9 ['007033', '1']
# 10 ['025035', '2']
# 11 ['025250', '2']
# 12 ['025328', '2']
# 13 ['024456', '2']
# 14 ['000074', '1']
# 15 ['000067', '1']
# 16 ['018192', '1']
# 17 ['000075', '1']
# 18 ['025265', '2']
# 19 ['005262', '1']
# 20 ['005263', '1']
# 21 ['005338', '1']
# 22 ['005186', '1']
# 23 ['024695', '5']
# 24 ['005180', '1']
# 25 ['022535', '2']
# 26 ['019171', '4']
# 27 ['005206', '1']
# 28 ['005330', '1']
# 29 ['005211', '1']
# 30 ['005212', '1']
# 31 ['012954', '3']
# 32 ['022920', '3']
# 33 ['016405', '5']
# 34 ['003930', '1']
# 35 ['003931', '1']
# 36 ['020222', '2']
# 37 ['021134', '2']
# 38 ['021786', '2']
# 39 ['000610', '1']
# 40 ['023652', '2']
# 41 ['021055', '2']
# 42 ['017885', '2']
# 43 ['017407', '2']
# 44 ['024711', '2']
# 45 ['024716', '2']
# 46 ['020146', '3']
# 47 ['021059', '2']
# 48 ['021822', '2']
# 49 ['022121', '2']
# 50 ['014812', '3']
# 51 ['005319', '1']
# 52 ['020131', '2']
# 53 ['022549', '4']
# 54 ['009813', '1']
# 55 ['021369', '3']
# 56 ['023545', '3']
# 57 ['012561', '2']
# 58 ['025597', '2']
# 59 ['018286', '2']
# 60 ['014317', '2']
# 61 ['017291', '2']
# 62 ['019367', '1']
# 63 ['021218', '2']
# 64 ['025599', '2']
# 65 ['025598', '2']
# 66 ['009281', '1']
# 67 ['018836', '2']
# 68 ['018837', '2']
# 69 ['019184', '2']
# 70 ['005616', '3']
# 71 ['018854', '2']
# 72 ['018855', '2']
# 73 ['022520', '2']
# 74 ['025653', '1']
# 75 ['016730', '1']
# 76 ['019767', '1']
# 77 ['003932', '1']
# 78 ['003937', '1']
# 79 ['000078', '1']
# 80 ['016731', '1']
# 81 ['024465', '2']
# 82 ['025641', '2']
# 83 ['024629', '3']
# 84 ['000041', '1']
# 85 ['015288', '1']
# 86 ['022147', '1']
# 87 ['023220', '1']
# 88 ['019733', '1']
# 89 ['023659', '1']
# 90 ['023888', '1']
# 91 ['025337', '1']
# 92 ['025061', '1']
# 93 ['022576', '1']
# 94 ['022532', '1']
# 95 ['024218', '3']
# 96 ['013884', '2']
# 97 ['024327', '1']
# 98 ['000608', '1']
# 99 ['000077', '1']
# 100 ['015253', '1']
# 101 ['019382', '2']
# 102 ['020750', '1']
# 103 ['021343', '1']
# 104 ['022531', '1']
# 105 ['022926', '1']
# 106 ['023219', '1']
# 107 ['024158', '1']
# 108 ['025297', '1']
# 109 ['000093', '1']
# 110 ['021344', '1']
# 111 ['016026', '2']
# 112 ['022165', '1']
# 113 ['022157', '1']
# 114 ['022931', '1']
# 115 ['023887', '1']
# 116 ['024156', '2']
# 117 ['025254', '2']
# 118 ['020483', '1']
# 119 ['020263', '1']
# 120 ['025114', '1']
# 121 ['025118', '1']
# 122 ['022235', '1']
# 123 ['025561', '3']
# 124 ['025403', '1']
# 125 ['000176', '1']
# 126 ['000177', '1']
# 127 ['016233', '1']
# 128 ['016234', '1']
# 129 ['020213', '2']
# 130 ['020148', '2']
# 131 ['020491', '2']
# 132 ['024244', '1']
# 133 ['020073', '2']
# 134 ['008860', '2']
# 135 ['022146', '2']
# 136 ['015849', '3']
# 137 ['024698', '1']
# 138 ['025060', '2']
# 139 ['021345', '1']
# 140 ['022248', '1']
# 141 ['021611', '1']
# 142 ['016235', '1']
# 143 ['016236', '1']
# 144 ['000170', '1']
# 145 ['000171', '1']
# 146 ['000175', '1']
# 147 ['022477', '2']
# 148 ['025697', '1']
# 149 ['005405', '1']
# 150 ['000661', '1']
# 151 ['021332', '2']
# 152 ['024182', '2']
# 153 ['025132', '2']
# 154 ['000051', '1']
# 155 ['020215', '2']
# 156 ['008618', '1']
# 157 ['002012', '1']
# 158 ['017288', '2']
# 159 ['020219', '2']
# 160 ['003376', '2']
# 161 ['023784', '2']
# 162 ['009410', '1']
# 163 ['021114', '2']
# 164 ['018888', '2']
# 165 ['000662', '1']
# 166 ['020785', '1']
# 167 ['023970', '1']
# 168 ['021044', '1']
# 169 ['022562', '1']
# 170 ['024264', '1']
# 171 ['024230', '1']
# 172 ['022604', '1']
# 173 ['022565', '1']
# 174 ['023941', '1']
# 175 ['016808', '1']
# 176 ['024499', '1']
# 177 ['023333', '1']
# 178 ['000200', '1']
# 179 ['000201', '1']
# 180 ['021779', '1']
# 181 ['000685', '2']
# 182 ['014299', '2']
# 183 ['021518', '2']
# 184 ['023396', '2']
# 185 ['016411', '1']
# 186 ['000205', '1']
# 187 ['020998', '1']
# 188 ['000206', '1']
# 189 ['021219', '1']
# 190 ['024660', '2']
# 191 ['015667', '1']
# 192 ['017930', '1']
# 193 ['021711', '1']
# 194 ['019527', '1']
# 195 ['022972', '1']
# 196 ['019535', '1']
# 197 ['022973', '1']
# 198 ['019536', '1']
# 199 ['022974', '1']
# 200 ['024536', '1']
# 201 ['024537', '1']
# 202 ['024538', '1']
# 203 ['001041', '1']
# 204 ['013166', '1']
# 205 ['015376', '1']
# 206 ['010373', '1']
# 207 ['001042', '1']
# 208 ['013168', '1']
# 209 ['004585', '1']
# 210 ['010374', '1']
# 211 ['001043', '1']
# 212 ['001044', '1']
# 213 ['020840', '1']
# 214 ['001049', '1']
# 215 ['001228', '1']
# 216 ['001229', '1']
# 217 ['020914', '1']
# 218 ['013573', '1']
# 219 ['020915', '1']
# 220 ['001231', '1']
# 221 ['001233', '1']
# 222 ['001235', '1']
# 223 ['013234', '1']
# 224 ['024866', '1']
# 225 ['013199', '1']
# 226 ['013202', '1']
# 227 ['013200', '1']
# 228 ['013201', '1']
# 229 ['013248', '1']
# 230 ['001004', '1']
# 231 ['018277', '1']
# 232 ['018276', '1']
# 233 ['001006', '1']
# 234 ['018275', '1']
# 235 ['001007', '1']
# 236 ['001008', '1']
# 237 ['001010', '1']
# 238 ['001011', '1']
# 239 ['021775', '1']
# 240 ['000001', '1']
# 241 ['022261', '1']
# 242 ['021417', '1']
# 243 ['021112', '2']
# 244 ['009189', '2']
# 245 ['009190', '2']
# 246 ['009191', '3']
# 247 ['014323', '1']
# 248 ['009271', '5']
# 249 ['022875', '1']
# 250 ['018561', '1']
# 251 ['019667', '2']
# 252 ['005287', '3']
# 253 ['023321', '1']
# 254 ['000040', '1']
# 255 ['014627', '1']
# 256 ['005346', '2']
# 257 ['022874', '2']
# 258 ['025298', '2']
# 259 ['024426', '1']
# 260 ['024180', '2']
# 261 ['018481', '1']
# 262 ['023207', '1']
# 263 ['000605', '2']
# 264 ['000028', '1']
# 265 ['014340', '1']
# 266 ['016080', '5']
# 267 ['020607', '3']
# 268 ['023323', '2']
# 269 ['009188', '2']
# 270 ['016082', '1']
# 271 ['000029', '1']
# 272 ['000019', '1']
# 273 ['005257', '2']
# 274 ['005258', '2']
# 275 ['016410', '1']
# 276 ['020160', '1']
# 277 ['019160', '2']
# 278 ['014649', '2']
# 279 ['020751', '1']
# 280 ['020277', '1']
# 281 ['025250', '3']
# 282 ['025057', '1']
# 283 ['020133', '4']
# 284 ['022542', '4']
# 285 ['003924', '3']
# 286 ['025034', '1']
# 287 ['009272', '5']
# 288 ['015472', '5']
# 289 ['020070', '2']
# 290 ['021448', '1']
# 291 ['022052', '1']
# 292 ['024726', '1']
# 293 ['021447', '1']
# 294 ['022160', '1']
# 295 ['004498', '2']
# 296 ['024709', '1']
# 297 ['025266', '1']
# 298 ['018565', '2']
# 299 ['019223', '3']
# 300 ['023660', '3']
# 301 ['019067', '1']
# 302 ['017077', '1']
# 303 ['001955', '2']
# 304 ['023169', '4']
# 305 ['024983', '2']
# 306 ['023843', '2']
# 307 ['019072', '1']
# 308 ['018777', '1']
# 309 ['020238', '1']
# 310 ['020896', '5']
# 311 ['025601', '1']
# 312 ['005616', '4']
# 313 ['001888', '2']
# 314 ['019055', '1']
# 315 ['023690', '2']
# 316 ['023214', '2']
# 317 ['014810', '3']
# 318 ['023929', '1']
# 319 ['016787', '2']
# 320 ['023878', '2']
# 321 ['015830', '2']
# 322 ['021954', '2']
# 323 ['021955', '2']
# 324 ['021956', '2']
# 325 ['023920', '1']
# 326 ['014635', '2']
# 327 ['021813', '2']
# 328 ['022536', '2']
# 329 ['024103', '1']
# 330 ['024924', '1']
# 331 ['024465', '1']
# 332 ['021140', '2']
# 333 ['024629', '1']
# 334 ['009242', '3']
# 335 ['014304', '1']
# 336 ['020782', '1']
# 337 ['012958', '1']
# 338 ['019052', '2']
# 339 ['023608', '3']
# 340 ['023287', '1']
# 341 ['023545', '1']
# 342 ['021369', '9']
# 343 ['022461', '2']
# 344 ['023604', '1']
# 345 ['023604', '1']
# 346 ['023313', '1']
# 347 ['023319', '1']
# 348 ['019731', '1']
# 349 ['000023', '1']
# 350 ['021328', '3']
# 351 ['019415', '1']
# 352 ['021095', '1']
# 353 ['022777', '1']
# 354 ['022767', '1']
# 355 ['019111', '1']
# 356 ['000010', '1']
# 357 ['021070', '1']
# 358 ['021847', '1']
# 359 ['016402', '1']
# 360 ['020119', '1']
# 361 ['022308', '1']
# 362 ['025059', '2']
# 363 ['021321', '3']
# 364 ['024148', '2']
# 365 ['023221', '1']
# 366 ['005244', '2']
# 367 ['024457', '2']
# 368 ['025693', '3']
# 369 ['025347', '4']
# 370 ['017073', '1']
# 371 ['009279', '3']
# 372 ['021411', '1']
# 373 ['024225', '1']
# 374 ['019775', '1']
# 375 ['025261', '1']
# 376 ['025243', '1']
# 377 ['025596', '1']
# 378 ['021347', '2']
# 379 ['021063', '2']
# 380 ['021141', '2']
# 381 ['013690', '1']
# 382 ['021450', '1']
# 383 ['021325', '1']
# 384 ['021437', '1']
# 385 ['021432', '1']
# 386 ['024200', '4']
# 387 ['024708', '4']
# 388 ['022129', '1']
# 389 ['019110', '1']
# 390 ['019776', '1']
# 391 ['019346', '1']
# 392 ['022582', '1']
# 393 ['023596', '1']
# 394 ['021120', '5']
# 395 ['021891', '2']
# 396 ['023237', '1']
# 397 ['023016', '1']
# 398 ['024697', '1']
# 399 ['023632', '1']
# 400 ['020148', '5']
# 401 ['024757', '1']
# 402 ['022581', '1']
# 403 ['024157', '1']
# 404 ['021861', '1']
# 405 ['022923', '1']
# 406 ['025602', '1']
# 407 ['025595', '1']
# 408 ['022871', '1']
# 409 ['021854', '1']
# 410 ['025066', '1']
# 411 ['019056', '1']
# 412 ['025055', '1']
# 413 ['020243', '3']
# 414 ['020243', '3']
# 415 ['023917', '1']
# 416 ['016467', '1']
# 417 ['021431', '1']
# 418 ['002454', '1']
# 419 ['022591', '1']
# 420 ['023994', '1']
# 421 ['000050', '1']
# 422 ['004879', '3']
# 423 ['000053', '1']
# 424 ['022413', '1']
# 425 ['021792', '2']
# 426 ['000051', '2']
# 427 ['020484', '1']
# 428 ['022584', '1']
# 429 ['023946', '1']
# 430 ['023635', '1']
# 431 ['022937', '1']
# 432 ['024447', '3']
# 433 ['024301', '1']
# 434 ['020878', '1']
# 435 ['023942', '2']
# 436 ['023285', '1']
# 437 ['022192', '1']
# 438 ['000056', '1']
# 439 ['022583', '1']
# 440 ['022601', '1']
# 441 ['021894', '1']
# 442 ['024790', '1']
# 443 ['023282', '1']
# 444 ['015177', '1']
# 445 ['017811', '1']
# 446 ['022907', '1']
# 447 ['000060', '1']
# 448 ['019875', '2']
# 449 ['025183', '1']
# 450 ['024487', '2']
# 451 ['025648', '2']
# 452 ['000057', '1']
# 453 ['018037', '1']
# 454 ['018674', '1']
# 455 ['000058', '1']
# 456 ['022538', '1']
# 457 ['017080', '1']
# 458 ['020879', '1']
# 459 ['019094', '1']
# 460 ['015176', '1']
# 461 ['019842', '1']
# 462 ['021896', '1']
# 463 ['019717', '1']
# 464 ['018023', '1']
# 465 ['000062', '1']
# 466 ['000061', '1']
# 467 ['021951', '1']
# 468 ['015885', '1']
# 469 ['018604', '1']
# 470 ['021897', '1']
# 471 ['018603', '1']
# 472 ['017081', '1']
# 473 ['020246', '2']
# 474 ['021509', '1']
# 475 ['020245', '2']
# 476 ['016108', '2']
# 477 ['017159', '1']
# 478 ['022602', '1']
# 479 ['023556', '1']
# 480 ['022405', '1']
# 481 ['022847', '1']
# 482 ['015281', '4']
# 483 ['023176', '1']
# 484 ['022026', '2']
# 485 ['024676', '1']
# 486 ['018029', '1']
# 487 ['019765', '1']
# 488 ['001873', '4']
# 489 ['024999', '2']
# 490 ['024426', '2']
# 491 ['021768', '1']
# 492 ['004558', '1']
# 493 ['021769', '1']
# 494 ['022108', '3']
# 495 ['023563', '1']
# 496 ['022989', '1']
# 497 ['003845', '3']
# 498 ['018102', '1']
# 499 ['025329', '1']
# 500 ['006321', '2']
# 501 ['019781', '2']
# 502 ['017078', '2']
# 503 ['022160', '2']
# 504 ['018715', '3']
# 505 ['021858', '1']
# 506 ['024152', '1']
# 507 ['021859', '1']
# 508 ['004565', '1']
# 509 ['012901', '1']
# 510 ['020269', '2']
# 511 ['017077', '6']
# 512 ['020222', '3']
# 513 ['020830', '1']
# 514 ['019110', '6']
# 515 ['019346', '7']
# 516 ['022593', '3']
# 517 ['024709', '3']
# 518 ['006322', '3']
# 519 ['023326', '3']
# 520 ['023920', '2']
# 521 ['023910', '2']
# 522 ['014341', '2']
# 523 ['023632', '2']
# 524 ['022997', '3']
# 525 ['020610', '2']
# 526 ['021369', '2']
# 527 ['021331', '2']
# 528 ['006320', '5']
# 529 ['013901', '2']
# 530 ['000040', '3']
# 531 ['024130', '2']
# 532 ['019451', '3']
# 533 ['019049', '2']
# 534 ['000028', '3']
# 535 ['016582', '3']
# 536 ['000029', '3']
# 537 ['016410', '3']
# 538 ['018481', '2']
# 539 ['016082', '2']
# 540 ['004492', '2']
# 541 ['016992', '3']
# 542 ['020119', '2']
# 543 ['022308', '2']
# 544 ['005278', '3']
# 545 ['009652', '4']
# 546 ['012958', '3']
# 547 ['019356', '6']
# 548 ['020782', '3']
# 549 ['021215', '3']
# 550 ['019055', '6']
# 551 ['000010', '7']
# 552 ['021303', '2']
# 553 ['023843', '1']
# 554 ['009310', '3']
# 555 ['025331', '5']
# 556 ['020517', '2']
# 557 ['006412', '2']
# 558 ['022133', '3']
# 559 ['025594', '6']
# 560 ['020567', '2']
# 561 ['022541', '3']
# 562 ['023929', '2']
# 563 ['017454', '1']
# 564 ['018442', '1']
# 565 ['004571', '1']
# 566 ['023901', '4']
# 567 ['006413', '1']
# 568 ['023655', '2']
# 569 ['004559', '3']
# 570 ['024200', '5']
# 571 ['013134', '3']
# 572 ['022309', '3']
# 573 ['003094', '3']
# 574 ['021370', '1']
# 575 ['020179', '2']
# 576 ['000638', '3']
# 577 ['024708', '5']
# 578 ['016771', '2']
# 579 ['023870', '2']
# 580 ['021128', '3']
# 581 ['022596', '3']
# 582 ['022872', '2']
# 583 ['004561', '2']
# 584 ['017075', '3']
# 585 ['015477', '1']
# 586 ['019432', '3']
# 587 ['016395', '3']
# 588 ['022331', '3']
# 589 ['022163', '3']
# 590 ['023016', '2']
# 591 ['008062', '2']
# 592 ['020227', '1']
# 593 ['020829', '3']
# 594 ['021119', '2']
# 595 ['021070', '3']
# 596 ['023237', '2']
# 597 ['023603', '2']
# 598 ['018104', '1']
# 599 ['022767', '4']
# 600 ['020113', '3']
# 601 ['022923', '2']
# 602 ['004562', '1']
# 603 ['022769', '3']
# 604 ['019112', '3']
# 605 ['023899', '2']
# 606 ['019651', '1']
# 607 ['020225', '1']
# 608 ['020226', '1']
# 609 ['021060', '2']
# 610 ['022452', '1']
# 611 ['024102', '3']
# 612 ['012996', '4']
# 613 ['024113', '4']
# 614 ['021783', '1']
# 615 ['013007', '2']
# 616 ['023275', '2']
# 617 ['025281', '3']
# 618 ['023912', '3']
# 619 ['025276', '3']
# 620 ['020788', '1']
# 621 ['018106', '1']
# 622 ['023931', '3']
# 623 ['023079', '1']
# 624 ['022250', '1']
# 625 ['004560', '1']
# 626 ['004567', '1']
# 627 ['019776', '3']
# 628 ['022582', '4']
# 629 ['024404', '2']
# 630 ['025656', '2']
# 631 ['020795', '4']
# 632 ['023324', '2']
# 633 ['024422', '1']
# 634 ['025004', '2']
# 635 ['024757', '2']
# 636 ['022581', '4']
# 637 ['018103', '1']
# 638 ['024365', '2']
# 639 ['025602', '5']
# 640 ['016424', '2']
# 641 ['025066', '3']
# 642 ['024679', '3']
# 643 ['021414', '1']
# 644 ['013920', '1']
# 645 ['020320', '1']
# 646 ['025031', '2']
# 647 ['015514', '1']
# 648 ['022584', '3']
# 649 ['025676', '3']
# 650 ['025132', '3']
# 651 ['022583', '5']
# 652 ['023940', '2']
# 653 ['024790', '2']
# 654 ['017811', '2']
# 655 ['022560', '2']
# 656 ['018229', '2']
# 657 ['021886', '3']
# 658 ['022899', '2']
# 659 ['023943', '2']
# 660 ['019368', '4']
# 661 ['020137', '2']
# 662 ['022193', '5']
# 663 ['018023', '2']
# 664 ['022186', '5']
# 665 ['000062', '2']
# 666 ['023805', '1']
# 667 ['023121', '1']
# 668 ['025131', '2']
# 669 ['018430', '4']
# 670 ['020484', '2']
# 671 ['020825', '2']
# 672 ['025666', '2']
# 673 ['021332', '5']
# 674 ['024182', '3']
# 675 ['023352', '1']
# 676 ['021845', '1']
# 677 ['019782', '1']
# 678 ['020671', '1']
# 679 ['025661', '1']
# 680 ['025662', '1']
# 681 ['025663', '1']
# 682 ['023556', '2']
# 683 ['025555', '3']
# 684 ['021181', '1']
# 685 ['025282', '2']
# 686 ['025076', '1']
# 687 ['000208', '1']
# 688 ['020185', '1']
# 689 ['018477', '1']
# 690 ['000210', '1']
# 691 ['020527', '1']
# 692 ['021103', '1']
# 693 ['000213', '1']
# 694 ['006490', '1']
# 695 ['000215', '1']
# 696 ['000219', '1']
# 697 ['018740', '1']
# 698 ['000222', '1']
# 699 ['000217', '1']
# 700 ['022502', '1']
# 701 ['022917', '1']
# 702 ['023193', '1']
# 703 ['024975', '1']
# 704 ['016995', '1']
# 705 ['000223', '1']
# 706 ['000224', '1']
# 707 ['018540', '1']
# 708 ['016306', '1']
# 709 ['016976', '1']
# 710 ['023836', '1']
# 711 ['023837', '1']
# 712 ['025499', '1']
# 713 ['017060', '1']
# 714 ['010571', '1']
# 715 ['010572', '1']
# 716 ['014607', '1']
# 717 ['016015', '1']
# 718 ['000506', '1']
# 719 ['000507', '1']
# 720 ['000512', '1']
# 721 ['000513', '1']
# 722 ['021100', '1']
# 723 ['000527', '1']
# 724 ['021898', '1']
# 725 ['022530', '1']
# 726 ['023314', '1']
# 727 ['022670', '1']
# 728 ['021899', '1']
# 729 ['023291', '1']
# 730 ['024424', '1']
# 731 ['000516', '1']
# 732 ['000517', '1']
# 733 ['022878', '1']
# 734 ['000526', '1']
# 735 ['000524', '1']
# 736 ['000525', '1']
# 737 ['021900', '1']
# 738 ['019337', '1']
# 739 ['025139', '1']
# 740 ['011685', '1']
# 741 ['021938', '1']
# 742 ['021610', '1']
# 743 ['000528', '1']
# 744 ['000529', '1']
# 745 ['000536', '1']
# 746 ['000538', '1']
# 747 ['000538', '1']
# 748 ['023565', '1']
# 749 ['006622', '1']
# 750 ['006623', '1']
# 751 ['025249', '1']
# 752 ['019809', '1']
# 753 ['000534', '1']
# 754 ['018085', '1']
# 755 ['017188', '1']
# 756 ['023827', '2']
# 757 ['000541', '1']
# 758 ['000542', '1']
# 759 ['011802', '4']
# 760 ['017366', '1']
# 761 ['002786', '1']
# 762 ['002762', '1']
# 763 ['002763', '1']
# 764 ['015846', '1']
# 765 ['002778', '1']
# 766 ['000563', '1']
# 767 ['023316', '2']
# 768 ['000546', '1']
# 769 ['000546', '1']
# 770 ['017082', '1']
# 771 ['017082', '1']
# 772 ['024143', '1']
# 773 ['024153', '1']
# 774 ['000550', '1']
# 775 ['000551', '1']
# 776 ['025626', '1']
# 777 ['021055', '4']
# 778 ['000587', '1']
# 779 ['024401', '1']
# 780 ['000616', '1']
# 781 ['013522', '1']
# 782 ['006449', '2']
# 783 ['025564', '2']
# 784 ['023216', '2']
# 785 ['021653', '1']
# 786 ['024371', '2']
# 787 ['023222', '1']
# 788 ['015180', '1']
# 789 ['000577', '1']
# 790 ['024712', '1']
# 791 ['024159', '1']
# 792 ['000585', '1']
# 793 ['020236', '1']
# 794 ['019348', '1']
# 795 ['000589', '1']
# 796 ['003297', '2']
# 797 ['000592', '1']
# 798 ['000593', '1']
# 799 ['025272', '1']
# 800 ['025272', '1']
# 801 ['023889', '1']
# 802 ['022171', '1']
# 803 ['000595', '1']
# 804 ['000600', '1']
# 805 ['000601', '1']
# 806 ['025594', '2']
# 807 ['000610', '2']
# 808 ['025018', '1']
# 809 ['017530', '1']
# 810 ['016047', '1']
# 811 ['024110', '1']
# 812 ['016048', '1']
# 813 ['009676', '2']
# 814 ['019384', '2']
# 815 ['000626', '1']
# 816 ['020168', '2']
# 817 ['021438', '1']
# 818 ['000569', '1']
# 819 ['000570', '1']
# 820 ['023238', '1']
# 821 ['014188', '1']
# 822 ['014204', '1']
# 823 ['014187', '1']
# 824 ['014203', '1']
# 825 ['000605', '1']
# 826 ['000629', '1']
# 827 ['017289', '1']
# 828 ['000621', '1']
# 829 ['000638', '1']
# 830 ['000637', '1']
# 831 ['022830', '1']
# 832 ['002789', '1']
# 833 ['021771', '1']
# 834 ['016601', '3']
# 835 ['020714', '4']
# 836 ['014159', '2']
# 837 ['024150', '3']
# 838 ['025000', '1']
# 839 ['000547', '3']
# 840 ['018857', '1']
# 841 ['000586', '1']
# 842 ['022780', '1']
# 843 ['024352', '2']
# 844 ['025494', '2']
# 845 ['018644', '7']
# 846 ['025254', '1']
# 847 ['023208', '2']
# 848 ['022769', '1']
# 849 ['023537', '1']
# 850 ['025681', '2']
# 851 ['000604', '1']
# 852 ['000602', '1']
# 853 ['024658', '1']
# 854 ['000608', '2']
# 855 ['000609', '1']
# 856 ['021311', '1']
# 857 ['000573', '1']
# 858 ['000594', '1']
# 859 ['016844', '1']
# 860 ['022017', '1']
# 861 ['024780', '1']
# 862 ['024960', '1']
# 863 ['025021', '1']
# 864 ['025022', '1']
# 865 ['025036', '1']
# 866 ['023525', '1']
# 867 ['010104', '2']
# 868 ['025602', '2']
# 869 ['023543', '1']
# 870 ['023524', '1']
# 871 ['025273', '1']
# 872 ['023523', '1']
# 873 ['014930', '1']
# 874 ['014949', '1']
# 875 ['014950', '1']
# 876 ['016441', '1']
# 877 ['020223', '1']
# 878 ['014202', '1']
# 879 ['014206', '1']
# 880 ['014189', '1']
# 881 ['014205', '1']
# 882 ['023527', '1']
# 883 ['000639', '1']
# 884 ['020239', '1']
# 885 ['023553', '2']
# 886 ['025109', '1']
# 887 ['000651', '1']
# 888 ['000652', '1']
# 889 ['017360', '1']
# 890 ['025698', '2']
# 891 ['025110', '1']
# 892 ['022810', '2']
# 893 ['023945', '2']
# 894 ['023045', '1']
# 895 ['022811', '4']
# 896 ['018028', '2']
# 897 ['016814', '3']
# 898 ['025132', '4']
# 899 ['000659', '1']
# 900 ['017133', '2']
# 901 ['000670', '1']
# 902 ['020169', '2']
# 903 ['023229', '2']
# 904 ['020553', '1']
# 905 ['023551', '2']
# 906 ['024216', '1']
# 907 ['024272', '2']
# 908 ['018789', '2']
# 909 ['024748', '1']
# 910 ['025351', '2']
# 911 ['000661', '2']
# 912 ['025111', '1']
# 913 ['018182', '2']
# 914 ['017362', '1']
# 915 ['022311', '2']
# 916 ['022561', '2']
# 917 ['022906', '4']
# 918 ['022905', '4']
# 919 ['000667', '1']
# 920 ['022014', '1']
# 921 ['020591', '2']
# 922 ['000648', '1']
# 923 ['000656', '1']
# 924 ['000662', '2']
# 925 ['000664', '1']
# 926 ['000665', '1']
# 927 ['000666', '1']
# 928 ['000671', '1']
# 929 ['020441', '2']
# 930 ['023247', '1']
# 931 ['022193', '2']
# 932 ['022186', '3']
# 933 ['023941', '2']
# 934 ['024182', '4']
# 935 ['024672', '1']
# 936 ['000675', '1']
# 937 ['000676', '1']
# 938 ['015994', '1']
# 939 ['015995', '1']
# 940 ['017037', '1']
# 941 ['017904', '1']
# 942 ['012910', '1']
# 943 ['012932', '1']
# 944 ['012933', '1']
# 945 ['024176', '3']
# 946 ['012935', '1']
# 947 ['000677', '1']
# 948 ['000680', '1']
# 949 ['000681', '1']
# 950 ['024777', '2']
# 951 ['000685', '1']
# 952 ['011629', '1']
# 953 ['000686', '1']
# 954 ['000689', '1']
# 955 ['000692', '1']
# 956 ['000693', '1']
# 957 ['016951', '1']
# 958 ['021229', '1']
# 959 ['022846', '1']
# 960 ['024991', '1']
# 961 ['025185', '1']
# 962 ['025678', '1']
# 963 ['025522', '1']
# 964 ['025213', '1']
# 965 ['022176', '3']
# 966 ['025576', '1']
# 967 ['020118', '2']
# 968 ['000698', '1']
# 969 ['015178', '1']
# 970 ['024995', '1']
# 971 ['015178', '1']
# 972 ['000694', '1']
# 973 ['000695', '1']
# 974 ['022624', '2']
# 975 ['024727', '2']
# 976 ['022625', '2']
# 977 ['024774', '1']
# 978 ['024799', '1']
# 979 ['024242', '1']
# 980 ['022833', '2']
# 981 ['023293', '1']
# 982 ['024706', '2']
# 983 ['017078', '6']
# 984 ['023845', '2']
# 985 ['021996', '5']
# 986 ['023276', '2']
# 987 ['005137', '3']
# 988 ['023620', '5']
# 989 ['002363', '2']
# 990 ['024200', '7']
# 991 ['001911', '7']
# 992 ['022585', '1']
# 993 ['024650', '1']
# 994 ['022292', '1']
# 995 ['022291', '1']
# 996 ['022290', '1']
# 997 ['022289', '1']
# 998 ['022076', '1']
# 999 ['023337', '1']
# 1000 ['022276', '1']
# 1001 ['022275', '1']
# 1002 ['022263', '1']
# 1003 ['022264', '1']
# 1004 ['000963', '1']
# 1005 ['000964', '1']
# 1006 ['000969', '1']
# 1007 ['019765', '3']
# 1008 ['013815', '1']
# 1009 ['023907', '1']
# 1010 ['022096', '1']
# 1011 ['022001', '1']
# 1012 ['024999', '1']
# 1013 ['025052', '1']
# 1014 ['000968', '1']
# 1015 ['023919', '3']
# 1016 ['018088', '1']
# 1017 ['020128', '2']
# 1018 ['022108', '2']
# 1019 ['000965', '1']
# 1020 ['000970', '1']
# 1021 ['000971', '1']
# 1022 ['016079', '4']
# 1023 ['000973', '1']
# 1024 ['013907', '2']
# 12580 ['019401', '1']
# 12581 ['018578', '1']
# 12582 ['002866', '1']
# 12583 ['024700', '1']
# 12584 ['023396', '4']
# 12585 ['024477', '1']
# 12586 ['015260', '1']
# 12587 ['002867', '1']
# 12588 ['019120', '1']
# 12589 ['002868', '1']
# 12590 ['017142', '1']
# 12591 ['016857', '1']
# 12592 ['002870', '1']
# 12593 ['015561', '1']
# 12594 ['017802', '1']
# 12595 ['016135', '1']
# 12596 ['025285', '1']
# 12597 ['015805', '1']
# 12598 ['016858', '1']
# 12599 ['002880', '1']
# 12600 ['015287', '2']
# 12601 ['002883', '1']
# 12602 ['021108', '1']
# 12603 ['002884', '1']
# 12604 ['019126', '1']
# 12605 ['014699', '1']
# 12606 ['013178', '1']
# 12607 ['020526', '1']
# 12608 ['011617', '1']
# 12609 ['018755', '1']
# 12610 ['019125', '1']
# 12611 ['002888', '1']
# 12612 ['002889', '1']
# 12613 ['015016', '1']
# 12614 ['016134', '1']
# 12615 ['018750', '1']
# 12616 ['017143', '1']
# 12617 ['019087', '1']
# 12618 ['015261', '1']
# 12619 ['018756', '1']
# 12620 ['014286', '1']
# 12621 ['018753', '1']
# 12622 ['015804', '1']
# 12623 ['021109', '1']
# 12624 ['021379', '1']
# 12625 ['021378', '1']
# 12626 ['021377', '1']
# 12627 ['021933', '1']
# 12628 ['022245', '1']
# 12629 ['023862', '1']
# 12630 ['023863', '1']
# 12631 ['015803', '1']
# 12632 ['023191', '1']
# 12633 ['025575', '1']
# 12634 ['002877', '1']
# 12635 ['021529', '1']
# 12636 ['017525', '1']
# 12637 ['017144', '1']
# 12638 ['018751', '1']
# 12639 ['021110', '1']
# 12640 ['015018', '1']
# 12641 ['019403', '1']
# 12642 ['025573', '1']
# 12643 ['002900', '1']
# 12644 ['002903', '1']
# 12645 ['002906', '1']
# 12646 ['014289', '2']
# 12647 ['014292', '1']
# 12648 ['019127', '1']
# 12649 ['002908', '1']
# 12650 ['016460', '1']
# 12651 ['016457', '1']
# 12652 ['021909', '1']
# 12653 ['022242', '1']
# 12654 ['022500', '2']
# 12655 ['023191', '1']
# 12656 ['024970', '2']
# 12657 ['018535', '1']

# %%
all_classes = []
for j in range(341,(len(ids_and_numbers))):
    if ids_and_numbers[j] == "skip":
        continue
    for k in range(len(all_terms)):
#         print k
        answer = make_course(ids_and_numbers[j][0],ids_and_numbers[j][1],all_terms[k])
        if answer != []:
            print answer
            all_classes.append(answer)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-231-4f34f73fac4f> in <module>()
#       5     for k in range(len(all_terms)):
#       6 #         print k
# ----> 7         answer = make_course(ids_and_numbers[j][0],ids_and_numbers[j][1],all_terms[k])
#       8         if answer != []:
#       9             print answer
#
# <ipython-input-150-8bd1310993f5> in make_course(course_id, course_offer_number, time_period)
#      11     url_full = url_section0 + url_section1 + url_section2 + url_section3 + url_section4 + url_section5 + url_section6 + token
#      12 #     print url_full
# ---> 13     data = rq.get(url_full).json()
#      14 #   if data["ssr_get_course_offering_resp"]["course_offering_result"]["ssr_crs_gen_msg"] == "***  This course has not been scheduled.  ***":
#      15 #         url = url_base
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/models.pyc in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/simplejson/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     516             parse_constant is None and object_pairs_hook is None
#     517             and not use_decimal and not kw):
# --> 518         return _default_decoder.decode(s)
#     519     if cls is None:
#     520         cls = JSONDecoder
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/simplejson/decoder.pyc in decode(self, s, _w, _PY3)
#     368         if _PY3 and isinstance(s, binary_type):
#     369             s = s.decode(self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#     372         if end != len(s):
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/simplejson/decoder.pyc in raw_decode(self, s, idx, _w, _PY3)
#     398             elif ord0 == 0xef and s[idx:idx + 3] == '\xef\xbb\xbf':
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
file_classes = open("Classes Progress.txt", "r") 
all_classes = []
for line in file_classes: 
    sections = line.split("',")
    if len(line) == 1:
        continue
    a = sections[0][2:]
    b = sections[1][2:]
    c = sections[2][2:]
    d = sections[3][2:]
    e = sections[4][2:]
    f = sections[5][2:]
    g = sections[6][2:]
    h = sections[7][2:]
    i = sections[8][2:]
    j = ",".join(sections[9:])[2:-3].replace("'","").replace(" ","").split(",")
    all_classes.append([a,b,c,d,e,f,g,h,i,j])

for course in all_classes:
    print course

print len(all_classes)
# Out:
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2012 Fall Term', 'Prereq: First year or Transfer students only', 'Tu 4:40PM - 7:10PM', 'Bivins 109', 'Bayo Holsey', ['S', 'CCI', 'SS']]
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2013 Spring Term', 'Prereq: First year or Transfer students only', 'TuTh 10:05AM - 11:20AM', 'Friedl Bldg 102', 'Wahneema Lubiano', ['S', 'ALP', 'CCI', 'CZ', 'EI']]
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2013 Fall Term', 'Prereq: First year or Transfer students only', 'Tu 4:40PM - 7:10PM', 'Friedl Bldg 240', 'Bayo Holsey', ['S', 'CCI', 'SS']]
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2014 Fall Term', 'Prereq: First year or Transfer students only', 'TBA', 'TBA', 'Staff', ['S', 'CCI', 'CZ', 'SS']]
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2015 Fall Term', 'Prereq: First year, First year with exception or Transfer students only', 'Tu 3:05PM - 5:35PM', 'Allen 226', 'Angel Harris', ['S', 'CCI', 'EI', 'SS']]
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2016 Spring Term', 'Prereq: First year, First year with exception or Transfer students only', 'M 12:00PM - 2:30PM', 'Biddle 069', 'Thomas Brothers', ['S', 'ALP', 'CCI']]
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2016 Fall Term', 'Prereq: First year, First year with exception or Transfer students only', 'WF 1:25PM - 2:40PM', 'Perkins LINK 079 (Seminar 3)', 'Janet J Ewald', ['S', 'CZ', 'EI', 'SS', 'R', 'W']]
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2017 Fall Term', 'Prereq: First year, First year with exception or Transfer students only', 'TuTh 11:45AM - 1:00PM', 'East Duke 204A', 'Lamonte Aidoo', ['S', 'ALP', 'CCI']]
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2018 Fall Term', 'Prereq: First year, First year with exception or Transfer students only', 'TuTh 11:45AM - 1:00PM', 'Carr 106', 'Lamonte Aidoo', ['S', 'ALP', 'CCI']]
# ['000064', 'FIRST-YEAR SEMINAR (TOP)', 'AAAS', ' 89S', '2019 Spring Term', 'Prereq: First year, First year with exception or Transfer students only', 'TuTh 11:45AM - 1:00PM', 'Carr 106', 'Lamonte Aidoo', ['S', 'ALP', 'CCI']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2012 Fall Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Trent Hall 038B', 'Sharon P Holland', ['CCI', 'CZ', 'SS']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2013 Spring Term', 'None', 'MW 1:25PM - 2:40PM', 'Friedl Bldg 240', 'Mark A Neal, \\n\\nThomas F DeFrantz', ['CCI', 'CZ', 'SS']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2013 Fall Term', 'None', 'WF 3:05PM - 4:20PM', 'Friedl Bldg 240', 'Wahneema Lubiano', ['CCI', 'CZ', 'SS']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2014 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Friedl Bldg 240', 'William A Darity', ['CCI', 'CZ', 'SS']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2014 Fall Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Friedl Bldg 240', 'Charmaine D Royal, \\n\\nWilliam A Darity', ['CCI', 'CZ', 'SS']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2015 Spring Term', 'None', 'TuTh 11:45AM - 1:00PM', 'Friedl Bldg 240', 'Thomas F DeFrantz', ['CCI', 'CZ', 'SS']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2015 Fall Term', 'None', 'TuTh 10:05AM - 11:20AM', 'Friedl Bldg 240', 'Wahneema Lubiano', ['CCI', 'CZ', 'SS']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2016 Spring Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Biddle 086', 'Angel Harris', ['CCI', 'CZ', 'SS']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2016 Fall Term', 'None', 'MW 11:45AM - 1:00PM', 'Friedl Bldg 240', 'Jasmine Nicole Cobb', ['CCI', 'CZ', 'SS']]
# ['000081', 'INTRO AFR-AMER STUDIES', 'AAAS', '102', '2017 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', '
Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['S', 'CCI', 'CZ', 'EI', 'SS', 'R']]
# ['020070', 'GTWY SEM: CIV RGHTS/ASIAN AMER', 'AAAS', '133S', '2013 Spring Term', 'None', 'W 4:40PM - 7:10PM', 'Carr 136', 'Sucheta Mazumdar', ['S', 'CCI', 'CZ', 'EI', 'SS', 'R']]
# ['020070', 'GTWY SEM: CIV RGHTS/ASIAN AMER', 'AAAS', '133S', '2014 Spring Term', 'None', 'W 4:40PM - 7:10PM', 'Carr 136', 'Sucheta Mazumdar', ['S', 'CCI', 'CZ', 'EI', 'SS', 'R']]
# ['020070', 'GTWY SEM: CIV RGHTS/ASIAN AMER', 'AAAS', '133S', '2017 Spring Term', 'None', 'Th 4:40PM - 7:05PM', 'Carr 106', 'Sucheta Mazumdar', ['S', 'CCI', 'CZ', 'EI', 'SS', 'R']]
# ['020070', 'GTWY SEM: CIV RGHTS/ASIAN AMER', 'AAAS', '133S', '2019 Spring Term', 'None', 'Th 4:40PM - 7:10PM', 'Carr 229', 'Sucheta Mazumdar', ['S', 'CCI', 'CZ', 'EI', 'SS', 'R']]
# ['020130', 'OLD WORLDS/NEW HISTORIES', 'AAAS', '134', '2012 Fall Term', 'None', 'TuTh 4:40PM - 5:55PM', 'Carr 240', 'Vasant Kaiwar', ['CCI', 'CZ', 'SS']]
# ['020130', 'OLD WORLDS/NEW HISTORIES', 'AAAS', '134', '2013 Fall Term', 'None', 'MW 11:45AM - 1:00PM', 'East Duke 204B', 'Vasant Kaiwar', ['CCI', 'CZ', 'SS']]
# ['020130', 'OLD WORLDS/NEW HISTORIES', 'AAAS', '134', '2014 Fall Term', 'None', 'TuTh 11:45AM - 1:00PM', 'East Duke 204D', 'Vasant Kaiwar', ['CCI', 'CZ', 'SS']]
# ['020130', 'OLD WORLDS/NEW HISTORIES', 'AAAS', '134', '2015 Fall Term', 'None', 'WF 11:45AM - 1:00PM', 'East Duke 204D', 'Vasant Kaiwar', ['CCI', 'CZ', 'SS']]
# ['020130', 'OLD WORLDS/NEW HISTORIES', 'AAAS', '134', '2016 Fall Term', 'None', 'WF 11:45AM - 1:00PM', 'East Duke 108', 'Vasant Kaiwar', ['CCI', 'CZ', 'SS']]
# ['020130', 'OLD WORLDS/NEW HISTORIES', 'AAAS', '134', '2018 Spring Term', 'None', 'WF 1:25PM - 2:40PM', 'Friedl Bldg 240', 'Vasant Kaiwar', ['CCI', 'CZ', 'SS']]
# ['020130', 'OLD WORLDS/NEW HISTORIES', 'AAAS', '134', '2018 Fall Term', 'None', 'WF 11:45AM - 1:00PM', 'Carr 137', 'Vasant Kaiwar', ['CCI', 'CZ', 'SS']]
# ['018580', 'INTRODUCTION TO JAZZ', 'AAAS', '140', '2012 Fall Term', 'None', 'MW 4:40PM - 5:55PM', 'White Lecture Hall 107', 'John V Brown Jr.', ['ALP', 'CCI']]
# ['018580', 'INTRODUCTION TO JAZZ', 'AAAS', '140', '2013 Fall Term', 'None', 'MW 4:40PM - 5:55PM', 'Biddle 104', 'John V Brown Jr.', ['ALP', 'CCI']]
# ['018580', 'INTRODUCTION TO JAZZ', 'AAAS', '140', '2014 Spring Term', 'None', 'MW 4:40PM - 5:55PM', 'White Lecture Hall 107', 'John V Brown Jr.', ['ALP', 'CCI']]
# ['018580', 'INTRODUCTION TO JAZZ', 'AAAS', '140', '2014 Fall Term', 'None', 'MW 4:40PM - 5:55PM', 'Biddle 101', 'John V Brown Jr.', ['ALP', 'CCI']]
# ['018580', 'INTRODUCTION TO JAZZ', 'AAAS', '140', '2015 Fall Term', 'None', 'MW 4:40PM - 5:55PM', 'East Duke 209', 'John V Brown Jr.', ['ALP', 'CCI']]
# ['018580', 'INTRODUCTION TO JAZZ', 'AAAS', '140', '2016 Spring Term', 'None', 'MW 4:40PM - 5:55PM', 'Biddle 104', 'John V Brown Jr.', ['ALP', 'CCI']]
# ['018580', 'INTRODUCTION TO JAZZ', 'AAAS', '140', '2016 Fall Term', 'None', 'MW 4:40PM - 5:55PM', 'Biddle 104', 'John V Brown Jr., \\n\\nScott Lee', ['ALP', 'CCI']]
# ['018580', 'INTRODUCTION TO JAZZ', 'AAAS', '140', '2017 Fall Term', 'None', 'MW 4:40PM - 5:55PM', 'Biddle 101', 'John V Brown Jr.', ['ALP', 'CCI']]
# ['018580', 'INTRODUCTION TO JAZZ', 'AAAS', '140', '2018 Fall Term', 'None', 'MW 4:40PM - 5:55PM', 'Biddle 101', 'John V Brown Jr.', ['ALP', 'CCI']]
# ['007033', 'INTRODUCTION TO JAZZ', 'AAAS', '140D', '2012 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['ALP', 'CCI']]
# ['007033', 'INTRODUCTION TO JAZZ', 'AAAS', '140D', '2013 Spring Term', 'None', 'MW 4:40PM - 5:55PM', 'Biddle 104', 'John V Brown Jr.', ['ALP', 'CCI']]
# ['007033', 'INTRODUCTION TO JAZZ', 'AAAS', '140D', '2015 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['ALP', 'CCI']]
# ['025035', 'MOTOWN AND AMERICAN SOUL MUSIC', 'AAAS', '146', '2018 Spring Term', 'None', 'Tu 4:40PM - 7:10PM', 'Biddle 104', 'Anthony M Kelley, \\n\\nMark A Neal', ['ALP', 'CCI', 'CZ']]
# ['025035', 'MOTOWN AND AMERICAN SOUL MUSIC', 'AAAS', '146', '2019 Spring Term', 'None', 'Tu 4:40PM - 7:10PM', 'Biddle 104', 'Anthony M Kelley, \\n\\nMark A Neal', ['ALP', 'CCI', 'CZ']]
# ['025250', 'GTWY: GANDHI, KING, MANDELA', 'AAAS', '163S', '2018 Fall Term', 'None', 'Tu 3:05PM - 5:35PM', 'Perkins LINK 079 (Seminar 3)', 'Sumathi Ramaswamy', ['S', 'CCI', 'CZ', 'EI', 'SS', 'R']]
# ['025328', 'BUSINESS ANTHROPOLOGY', 'AAAS', '171', '2018 Fall Term', 'None', 'TuTh 11:45AM - 1:00PM', 'Sociology Psychology 126', 'Anne-Maria B Makhulu', ['CCI', 'SS']]
# ['024456', 'GTWY: AM SLAVERY & FREEDOM', 'AAAS', '182S', '2017 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Carr 106', 'Thavolia Glymph', ['S', 'ALP', 'CCI', 'CZ', 'R', 'W']]
# ['000074', 'SPECIAL TOPICS', 'AAAS', '190', '2018 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['']]
# ['000074', 'SPECIAL TOPICS', 'AAAS', '190', '2019 Spring Term', 'None', 'MW 8:30AM - 9:45AM', 'Allen 103', 'Kerry L Haynie', ['SS']]
# ['018192', 'FOCUS SEMINARS (TOP)', 'AAAS', '190FS', '2014 Fall Term', 'None', 'MW 11:45AM - 1:00PM', 'Friedl Bldg 216', 'Charmaine D Royal', ['S', 'EI', 'SS', 'STS']]
# ['018192', 'FOCUS SEMINARS (TOP)', 'AAAS', '190FS', '2018 Fall Term', 'None', 'TuTh 11:45AM - 1:00PM', 'Old Chemistry 123', 'Joseph Winters', ['S', 'CCI', 'EI', 'SS']]
# ['000075', 'SPECIAL TOPICS', 'AAAS', '190S', '2012 Fall Term', 'None', 'TuTh 6:15PM - 7:30PM', 'Biddle 086', 'Bradley E Simmons', ['S', 'ALP', 'CCI']]
# ['000075', 'SPECIAL TOPICS', 'AAAS', '190S', '2013 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['S']]
# ['000075', 'SPECIAL TOPICS', 'AAAS', '190S', '2015 Spring Term', 'None', 'MW 10:05AM - 11:20AM', 'Carr 241', 'Thavolia Glymph', ['S', 'CCI', 'CZ', 'EI', 'SS']]
# ['000075', 'SPECIAL TOPICS', 'AAAS', '190S', '2015 Fall Term', 'None', 'W 3:05PM - 5:35PM', 'West Duke 108A', 'Stephanie Hassell', ['S', 'CZ', 'R', 'W']]
# ['000075', 'SPECIAL TOPICS', 'AAAS', '190S', '2016 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['S']]
# ['000075', 'SPECIAL TOPICS', 'AAAS', '190S', '2016 Fall Term', 'None', 'MW 3:05PM - 4:20PM', 'Sociology Psychology 128', 'Sasha Ann Panaram', ['S', 'ALP', 'EI', 'W']]
# ['000075', 'SPECIAL TOPICS', 'AAAS', '190S', '2017 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['S']]
# ['000075', 'SPECIAL TOPICS', 'AAAS', '190S', '2018 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['S']]
# ['000075', 'SPECIAL TOPICS', 'AAAS', '190S', '2018 Fall Term', 'None', 'WF 3:05PM - 4:20PM', 'Crowell Building 107', 'Anastasija Karklina', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'W']]
# ['025265', 'PATIENT ACTIVISM AND ADVOCACY', 'AAAS', '196FS', '2018 Fall Term', 'None', 'TuTh 1:25PM - 2:40PM', 'North Building 232', 'Misha Angrist', ['S', 'SS', 'STS', 'W']]
# ['005262', 'AFRICANS IN AMERICA TO 1865', 'AAAS', '206', '2012 Fall Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Carr 103', 'Raymond Gavins', ['CCI', 'CZ', 'EI']]
# ['005262', 'AFRICANS IN AMERICA TO 1865', 'AAAS', '206', '2013 Fall Term', 'None', 'TuTh 1:25PM - 2:40PM', 
# ['005211', 'CARIBBEAN 1492-1700', 'AAAS', '218', '2017 Fall Term', 'None', 'MWF 1:40PM - 2:30PM', 'French Science 2237', 'Barry Gaspar', ['CCI', 'CZ']]
# ['005211', 'CARIBBEAN 1492-1700', 'AAAS', '218', '2018 Fall Term', 'None', 'MW 1:25PM - 2:40PM', 'Friedl Bldg 107', 'Barry Gaspar', ['CCI', 'CZ']]
# ['005212', 'WAR, SLAVERY, AND REVOLUTION', 'AAAS', '219', '2013 Spring Term', 'None', 'MWF 12:00PM - 12:50PM', 'West Duke 106', 'Barry Gaspar', ['CCI', 'CZ']]
# ['005212', 'WAR, SLAVERY, AND REVOLUTION', 'AAAS', '219', '2014 Spring Term', 'None', 'MWF 12:00PM - 12:50PM', 'Friedl Bldg 240', 'Barry Gaspar', ['CCI', 'CZ']]
# ['005212', 'WAR, SLAVERY, AND REVOLUTION', 'AAAS', '219', '2015 Spring Term', 'None', 'MWF 12:00PM - 12:50PM', 'West Duke 106', 'Barry Gaspar', ['CCI', 'CZ']]
# ['005212', 'WAR, SLAVERY, AND REVOLUTION', 'AAAS', '219', '2016 Spring Term', 'None', 'MWF 1:40PM - 2:30PM', 'West Duke 106', 'Barry Gaspar', ['CCI', 'CZ']]
# ['005212', 'WAR, SLAVERY, AND REVOLUTION', 'AAAS', '219', '2017 Spring Term', 'None', 'MWF 1:40PM - 2:30PM', 'East Duke 204D', 'Barry Gaspar', ['CCI', 'CZ']]
# ['005212', 'WAR, SLAVERY, AND REVOLUTION', 'AAAS', '219', '2018 Spring Term', 'None', 'MW 1:25PM - 2:40PM', 'East Duke 204D', 'Barry Gaspar', ['CCI', 'CZ']]
# ['012954', 'W AFR ROOTHOLDS IN DANCE', 'AAAS', '220', '2013 Spring Term', 'None', 'Tu 1:25PM - 2:55PM', 'Carr 136', 'Ava Vinesett', ['ALP', 'CCI', 'CZ']]
# ['022920', 'CAPOEIRA: PRACTICE AND CULTURE', 'AAAS', '221SL', '2014 Fall Term', 'None', 'F 3:05PM - 4:35PM', 'Bivins 214', 'Katya Wesolowski', ['S', 'ALP', 'CCI', 'SS', 'W']]
# ['016405', 'DANCE/RELIGION IN ASIA/AFRICA', 'AAAS', '222', '2014 Spring Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Friedl Bldg 240', 'Ava Vinesett, \\n\\nPurnima Shah', ['ALP', 'CCI', 'CZ']]
# ['016405', 'DANCE/RELIGION IN ASIA/AFRICA', 'AAAS', '222', '2016 Spring Term', 'None', 'MW 11:45AM - 1:00PM', 'Friedl Bldg 240', 'Ava Vinesett, \\n\\nPurnima Shah', ['ALP', 'CCI', 'CZ']]
# ['003930', 'AFRICAN AMERICAN LIT', 'AAAS', '223', '2014 Spring Term', 'None', 'TuTh 11:45AM - 1:00PM', 'Sociology Psychology 126', 'Maurice O Wallace', ['ALP', 'CCI', 'R']]
# ['003930', 'AFRICAN AMERICAN LIT', 'AAAS', '223', '2015 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['ALP', 'CCI', 'R']]
# ['003931', 'AFRICAN AMERICAN LIT', 'AAAS', '224', '2013 Spring Term', 'None', 'WF 1:25PM - 2:40PM', 'Biological Sciences 063', 'Allison S Curseen', ['ALP']]
# ['003931', 'AFRICAN AMERICAN LIT', 'AAAS', '224', '2013 Fall Term', 'None', 'MW 11:45AM - 1:00PM', 'Allen 326', 'Karla F Holloway', ['ALP']]
# ['003931', 'AFRICAN AMERICAN LIT', 'AAAS', '224', '2015 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['ALP']]
# ['020222', 'DOCUMENTING BLACK EXPERIENCES', 'AAAS', '225S', '2015 Fall Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'ALP', 'CCI']]
# ['020222', 'DOCUMENTING BLACK EXPERIENCES', 'AAAS', '225S', '2016 Fall Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'ALP', 'CCI']]
# ['020222', 'DOCUMENTING BLACK EXPERIENCES', 'AAAS', '225S', '2017 Fall Term', 'None', 'Tu 11:45AM - 2:15PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'ALP', 'CCI']]
# ['020222', 'DOCUMENTING BLACK EXPERIENCES', 'AAAS', '225S', '2018 Spring Term', 'None', 'Tu 11:45AM - 2:15PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'ALP', 'CCI']]
# ['020222', 'DOCUMENTING BLACK EXPERIENCES', 'AAAS', '225S', '2018 Fall Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'ALP', 'CCI']]
# ['020222', 'DOCUMENTING BLACK EXPERIENCES', 'AAAS', '225S', '2019 Spring Term', 'None', 'Tu 11:45AM - 2:15PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'ALP', 'CCI']]
# ['021134', 'CRIME AND THE CITY', 'AAAS', '226', '2015 Spring Term', 'None', 'MWF 10:20AM - 11:10AM', 'Old Chemistry 201', 'Susan Thorne', ['ALP', 'CCI', 'EI', 'SS']]
# ['021134', 'CRIME AND THE CITY', 'AAAS', '226', '2015 Fall Term', 'None', 'TuTh 8:30AM - 9:45AM', 'Allen 326', 'Susan Thorne', ['ALP', 'CCI', 'EI', 'SS']]
# ['021134', 'CRIME AND THE CITY', 'AAAS', '226', '2016 Spring Term', 'None', 'MW 10:05AM - 10:55AM', 'Sociology Psychology 129', 'Susan Thorne', ['ALP', 'CCI', 'EI', 'SS']]
# ['021134', 'CRIME AND THE CITY', 'AAAS', '226', '2017 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Allen 326', 'Susan Thorne', ['ALP', 'CCI', 'EI', 'SS']]
# ['021134', 'CRIME AND THE CITY', 'AAAS', '226', '2018 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['ALP', 'CCI', 'EI', 'SS']]
# ['021134', 'CRIME AND THE CITY', 'AAAS', '226', '2019 Spring Term', 'None', 'WF 10:05AM - 11:20AM', 'Carr 114', 'Susan Thorne', ['ALP', 'CCI', 'EI', 'SS']]
# ['021786', 'CRIME AND THE CITY', 'AAAS', '226D', '2014 Spring Term', 'None', 'MW 8:30AM - 9:20AM', 'Allen 326', 'Susan Thorne', ['ALP', 'CCI', 'EI', 'SS']]
# ['021786', 'CRIME AND THE CITY', 'AAAS', '226D', '2016 Spring Term', 'None', 'MW 10:05AM - 10:55AM', 'Sociology Psychology 129', 'Susan Thorne', ['ALP', 'CCI', 'EI', 'SS']]
# ['000610', 'AFRICAN AMERICAN ART', 'AAAS', '227', '2012 Fall Term', 'None', 'MW 11:45AM - 1:00PM', 'East Duke 108', 'Richard J Powell', ['ALP', 'CCI', 'CZ', 'R']]
# ['000610', 'AFRICAN AMERICAN ART', 'AAAS', '227', '2013 Fall Term', 'None', 'MW 11:45AM - 1:00PM', 'East Duke 108', 'Richard J Powell, \\n\\nShahrazad Aliyah Shareef', ['ALP', 'CCI', 'CZ', 'R']]
# ['000610', 'AFRICAN AMERICAN ART', 'AAAS', '227', '2014 Fall Term', 'None', 'MW 1:25PM - 2:40PM', 'East Duke 108', 'Mora Beauchamp-Byrd, \\n\\nShahrazad Aliyah Shareef', ['ALP', 'CCI', 'CZ', 'R']]
# ['000610', 'AFRICAN AMERICAN ART', 'AAAS', '227', '2015 Fall Term', 'None', 'WF 10:05AM - 11:20AM', 'East Duke 209', 'Richard J Powell', ['ALP', 'CCI', 'CZ', 'R']]
# ['000610', 'AFRICAN AMERICAN ART', 'AAAS', '227', '2018 Spring Term', 'None', 'TuTh 10:05AM - 11:20AM', 'Smith Warehouse Bay 10 A266', 'Richard J Powell', ['ALP', 'CCI', 'CZ', 'R']]
# ['023652', 'FICTIONS THAT MARK THE MOMENT', 'AAAS', '228S', '2015 Fall Term', 'None', 'MW 10:05AM - 11:20AM', 'Friedl Bldg 102', 'Wahneema Lubiano', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'R']]
# ['023652', 'FICTIONS THAT MARK THE MOMENT', 'AAAS', '228S', '2016 Fall Term', 'None', 'WF 1:25PM - 2:40PM', 'Friedl Bldg 216', 'Wahneema Lubiano', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'R']]
# ['023652', 'FICTIONS THAT MARK THE MOMENT', 'AAAS', '228S', '2019 Spring Term', 'None', 'MW 3:05PM - 4:20PM', 'Friedl Bldg 126', 'Wahneema Lubiano', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'R']]
# ['017885', 'THE SOUTH IN BLACK AND WHITE', 'AAAS', '230', '2013 Spring Term', 'None', 'Tu 6:15PM - 8:45PM', 'Bridges House 007', 'Timothy B Tyson', ['ALP', 'CCI', 'CZ']]
# ['017885', 'THE SOUTH IN BLACK AND WHITE', 'AAAS', '230', '2014 Spring Term', 'None', 'Tu 6:15PM - 8:45PM', 'Bridges House 007', 'Timothy B Tyson', ['ALP', 'CCI', 'CZ']]
# ['017885', 'THE SOUTH IN BLACK AND WHITE', 'AAAS', '230', '2015 Spring Term', 'None', 'Tu 6:30PM - 9:00PM', 'See Instructor/Department', 'Timothy B Tyson', ['ALP', 'CCI', 'CZ']]
# ['017885', 'THE SOUTH IN BLACK AND WHITE', 'AAAS', '230', '2016 Spring Term', 'None', 'Tu 6:30PM - 9:00PM', 'See Instructor/Department', 'Timothy B Tyson', ['ALP', 'CCI', 'CZ']]
# ['017885', 'THE SOUTH IN BLACK AND WHITE', 'AAAS', '230', '2017 Spring Term', 'None', 'Tu 6:30PM - 9:30PM', 'See Instructor/Department', 'Mary D Williams, \\n\\nTimothy B Tyson', ['ALP', 'CCI', 'CZ']]
# ['017407', 'DOCUMENTING BLACK POWER', 'AAAS', '231S', '2012 Fall Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 113', 'Timothy B Tyson', ['S', 'ALP', 'CCI', 'CZ']]
# ['017407', 'DOCUMENTING BLACK POWER', 'AAAS', '231S', '2013 Fall Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 113', 'Timothy B Tyson', ['S', 'ALP', 'CCI', 'CZ']]
# ['017407', 'DOCUMENTING BLACK POWER', 'AAAS', '231S', '2014 Spring Term', 'None', 'Th 3:05PM - 5:35PM', 'Bridges House 201', 'Timothy B Tyson', ['S', 'ALP', 'CCI', 'CZ']]
# ['017407', 'DOCUMENTING BLACK POWER', 'AAAS', '231S', '2014 Fall Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 113', 'Timothy B Tyson', ['S', 'ALP', 'CCI', 'CZ']]
# ['017407', 'DOCUMENTING BLACK POWER', 'AAAS', '231S', '2015 Spring Term', 'None', 'W 3:05PM - 5:35PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'ALP', 'CCI', 'CZ']]
# ['017407', 'DOCUMENTING BLACK POWER', 'AAAS', '231S', '2016 Spring Term', 'None', 'W 3:05PM - 5:35PM', 'Bridges House 113', 'Timothy B Tyson', ['S', 'ALP', 'CCI', 'CZ']]
# ['024711', 'RACE, POWER, AND IDENTITY', 'AAAS', '232', '2017 Fall Term', 'None', 'MW 3:05PM - 4:20PM', 'West Duke 08A', 'Martin Paul Smith', ['CCI', 'EI', 'SS', 'R']]
# ['024711', 'RACE, POWER, AND IDENTITY', 'AAAS', '232', '2018 Spring Term', 'None', 'MW 3:05PM - 4:20PM', 'East Duke 204D', 'Martin Paul Smith', ['CCI', 'EI', 'SS', 'R']]
# ['024711', 'RACE, POWER, AND IDENTITY', 'AAAS', '232', '2018 Fall Term', 'None', 'TuTh 3:05PM - 4:20PM', 'East Duke 204D', 'Martin Paul Smith', ['CCI', 'EI', 'SS', 'R']]
# ['024711', 'RACE, POWER, AND IDENTITY', 'AAAS', '232', '2019 Spring Term', 'None', 'MW 3:05PM - 4:20PM', 'East Duke 108', 'Martin Paul Smith', ['CCI', 'EI', 'SS', 'R']]
# ['024716', 'WRITING AMERICAN POLITICS', 'AAAS', '233S', '2017 Fall Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'CZ', 'EI', 'SS', 'R', 'W']]
# ['024716', 'WRITING AMERICAN POLITICS', 'AAAS', '233S', '2018 Spring Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'CZ', 'EI', 'SS', 'R', 'W']]
# ['024716', 'WRITING AMERICAN POLITICS', 'AAAS', '233S', '2019 Spring Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 001', 'Timothy B Tyson', ['S', 'CZ', 'EI', 'SS', 'R', 'W']]
# ['020146', 'CIVIL/HUMAN RIGHTS ACTIVISM', 'AAAS', '236S', '2012 Fall Term', 'None', 'Tu 3:05PM - 5:35PM', 'Bridges House 113', 'Barbara A Lau', ['S', 'ALP', 'CCI', 'CZ', 'R']]
# ['020146', 'CIVIL/HUMAN RIGHTS ACTIVISM', 'AAAS', '236S', '2013 Fall Term', 'None', 'W 3:05PM - 5:35PM', 'Bridges House 113', 'Barbara A Lau', ['S', 'ALP', 'CCI', 'CZ', 'R']]
# ['020146', 'CIVIL/HUMAN RIGHTS ACTIVISM', 'AAAS', '236S', '2014 Fall Term', 'None', 'W 3:05PM - 5:35PM', 'Bridges House 113', 'Barbara A Lau', ['S', 'ALP', 'CCI', 'CZ', 'R']]
# ['020146', 'CIVIL/HUMAN RIGHTS ACTIVISM', 'AAAS', '236S', '2015 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['S', 'ALP', 'CCI', 'CZ', 'R']]
# ['021059', 'MODERN CARIBBEAN', 'AAAS', '240', '2013 Spring Term', 'None', 'TuTh 10:05AM - 11:20AM', 'Allen 304I', 'Johnhenry Gonzalez', ['CCI', 'CZ']]
# ['021059', 'MODERN CARIBBEAN', 'AAAS', '240', '2014 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['CCI', 'CZ']]
# ['021059', 'MODERN CARIBBEAN', 'AAAS', '240', '2015 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Friedl Bldg 107', 'Laurent M Dubois', ['CCI', 'CZ']]
# ['021059', 'MODERN CARIBBEAN', 'AAAS', '240', '2016 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Friedl Bldg 126', 'Laurent M Dubois', ['CCI', 'CZ']]
# ['021059', 'MODERN CARIBBEAN', 'AAAS', '240', '2018 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Carr 240', 'Christina Davidson', ['CCI', 'CZ']]
# ['021059', 'MODERN CARIBBEAN', 'AAAS', '240', '2019 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Social Sciences 124', 'Laurent M Dubois', ['CCI', 'CZ']]
# ['021822', 'GENDER, RACE, ETHNICITY IN POL', 'AAAS', '241', '2013 Spring Term', 'None', 'M 11:45AM - 1:00PM', 'Physics 259', 'Kerry L Haynie', ['SS']]
# ['022121', 'DOCUMENTING BLACK', 'AAAS', '241S', '2013 Fall Term', 'None', 'Tu 11:45AM - 2:15PM', 'Bridges House 113', 'Timothy B Tyson', ['S', 'ALP', 'CCI', 'CZ']]
# ['014812', 'RACE, GENDER, AND SEXUALITY', 'AAAS', '242S', '2012 Fall Term', 'None', 'TuTh 10:05AM - 11:20AM', 'White 201', 'Clare Counihan', ['S', 'CCI', 'SS']]
# ['014812', 'RACE, GENDER, AND SEXUALITY', 'AAAS', '242S', '2013 Fall Term', 'None', 'TuTh 4:40PM - 5:55PM', 'White 201', 'Stephanie Clare', ['S', 'CCI', 'SS']]
# ['014812', 'RACE, GENDER, AND SEXUALITY', 'AAAS', '242S', '2015 Spring Term', 'None', 'WF 11:45AM - 1:00PM', 'Crowell Building 107', 'Ross Brian Truscott', ['S', 'CCI', 'SS']]
# ['014812', 'RACE, GENDER, AND SEXUALITY', 'AAAS', '242S', '2016 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'East Duke 204A', 'Kimberly K Lamm', ['S', 'CCI', 'SS']]
# ['014812', 'RACE, GENDER, AND SEXUALITY', 'AAAS', '242S', '2017 Fall Term', 'None', 'WF 8:30AM - 9:45AM', 'Friedl Bldg 216', 'Brenna Casey', ['S', 'CCI', 'SS']]
# ['014812', 'RACE, GENDER, AND SEXUALITY', 'AAAS', '242S', '2018 Fall Term', 'None', 'WF 11:45AM - 1:00PM', 'Crowell Building 107', 'Patrice D Douglass', ['S', 'CCI', 'SS']]
# ['005319', 'CIVIL RIGHTS MOVEMENT', 'AAAS', '243', '2013 Spring Term', 'None', 'TuTh 11:45AM - 1:00PM', 'Carr 240', 'Raymond Gavins', ['CCI', 'CZ', 'EI', 'SS']]
# ['005319', 'CIVIL RIGHTS MOVEMENT', 'AAAS', '243', '2014 Spring Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Allen 103', 'Raymond Gavins', ['CCI', 'CZ', 'EI', 'SS']]
# ['005319', 'CIVIL RIGHTS MOVEMENT', 'AAAS', '243', '2015 Spring Term', 'None', 'TuTh 1:25PM - 2:40PM', 'West Duke 202', 'Raymond Gavins', ['CCI', 'CZ', 'EI', 'SS']]
# ['005319', 'CIVIL RIGHTS MOVEMENT', 'AAAS', '243', '2015 Fall Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Carr 103', 'Raymond Gavins', ['CCI', 'CZ', 'EI', 'SS']]
# ['005319', 'CIVIL RIGHTS MOVEMENT', 'AAAS', '243', '2016 Spring Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Carr 137', 'Raymond Gavins', ['CCI', 'CZ', 'EI', 'SS']]
# ['005319', 'CIVIL RIGHTS MOVEMENT', 'AAAS', '243', '2016 Fall Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Carr 240', 'Adriane Lentz-Smith', ['CCI', 'CZ', 'EI', 'SS']]
# ['005319', 'CIVIL RIGHTS MOVEMENT', 'AAAS', '243', '2017 Fall Term', 'None', 'TuTh 1:25PM - 2:40PM', 'East Duke 204B', 'Christina Davidson', ['CCI', 'CZ', 'EI', 'SS']]
# ['005319', 'CIVIL RIGHTS MOVEMENT', 'AAAS', '243', '2018 Fall Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Carr 240', 'Adriane Lentz-Smith', ['CCI', 'CZ', 'EI', 'SS']]
# ['022549', 'ACTIVISM, WOMEN AND DANGER', 'AAAS', '245S', '2016 Spring Term', 'None', 'W 11:45AM - 2:15PM', 'Bridges House 113', 'Wesley C Hogan', ['S', 'CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2012 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2013 Spring Term', 'None', 'MW 1:25PM - 2:40PM', 'Languages 211', 'Eduardo Bonilla-Silva', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2013 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2014 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2015 Spring Term', 'None', 'MW 10:05AM - 11:20AM', 'Biological Sciences 063', 'Eduardo Bonilla-Silva', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2016 Spring Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Sociology Psychology 237', 'Richard N Pitt', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2017 Spring Term', 'None', 'MW 3:05PM - 4:20PM', 'Social Sciences 113', 'Eduardo Bonilla-Silva', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2017 Fall Term', 'None', 'MW 1:25PM - 2:40PM', 'Allen 326', 'Eduardo Bonilla-Silva, \\n\\nLiann Haruka Yamashita', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2018 Spring Term', 'None', 'MW 3:05PM - 4:20PM', 'Allen 326', 'Eduardo Bonilla-Silva, \\n\\nLiann Haruka Yamashita', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2018 Fall Term', 'None', 'MW 4:40PM - 5:55PM', 'Languages 211', 'Simon G Brauer, \\n\\nTyson H Brown', ['CCI', 'EI', 'SS', 'R']]
# ['009813', 'SOCIOLOGY OF RACISM IN AMERICA', 'AAAS', '246', '2019 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Allen 326', 'Tyson H Brown', ['CCI', 'EI', 'SS', 'R']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2012 Fall Term', 'None', 'Tu 10:05AM - 12:30PM', 'Friedl Bldg 102', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2013 Spring Term', 'None', 'Tu 10:05AM - 12:35PM', 'Crowell Building 107', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2013 Fall Term', 'None', 'Tu 10:05AM - 12:35PM', 'Friedl Bldg 102', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2014 Spring Term', 'None', 'Tu 10:05AM - 12:35PM', 'Biddle 101', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2014 Fall Term', 'None', 'Tu 10:05AM - 12:35PM', 'Carr 106', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2015 Spring Term', 'None', 'MW 1:25PM - 2:40PM', 'Friedl Bldg 102', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2016 Spring Term', 'None', 'MW 11:45AM - 1:00PM', 'Friedl Bldg 102', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2016 Fall Term', 'None', 'M 3:05PM - 5:35PM', 'Friedl Bldg 102', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2017 Fall Term', 'None', 'MW 11:45AM - 1:00PM', 'Friedl Bldg 102', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2018 Spring Term', 'None', 'MW 11:45AM - 1:00PM', 'Friedl Bldg 102', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2018 Fall Term', 'None', 'WF 11:45AM - 1:00PM', 'Friedl Bldg 102', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['021369', 'SOCIAL MOVEMENTS/SOCIAL MEDIA', 'AAAS', '247S', '2019 Spring Term', 'None', 'WF 11:45AM - 1:00PM', 'Friedl Bldg 225', 'Negar Mottahedeh', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'STS']]
# ['023545', 'MARTIN LUTHER KING', 'AAAS', '249', '2015 Fall Term', 'None', 'Tu 4:55PM - 7:45PM', 'Franklin Center 028', 'Omid Safi', ['CCI', 'CZ', 'EI', 'SS', 'R']]
# ['012561', 'ANTHROPOLOGY OF RACE', 'AAAS', '251', '2012 Fall Term', 'None', 'TuTh 10:05AM - 11:20AM', 'Perkins LINK (071) classroom 5', 'Lee D Baker', ['CCI', 'EI', 'SS']]
# ['012561', 'ANTHROPOLOGY OF RACE', 'AAAS', '251', '2013 Fall Term', 'None', 'TuTh 10:05AM - 11:20AM', 'Perkins LINK (071) classroom 5', 'Lee D Baker', ['CCI', 'EI', 'SS']]
# ['012561', 'ANTHROPOLOGY OF RACE', 'AAAS', '251', '2017 Spring Term', 'None', 'TuTh 11:45AM - 1:00PM', 'Carr 240', 'Lee D Baker', ['CCI', 'EI', 'SS']]
# ['012561', 'ANTHROPOLOGY OF RACE', 'AAAS', '251', '2018 Fall Term', 'None', 'TuTh 10:05AM - 11:20AM', 'Friedl Bldg 204', 'Lee D Baker', ['CCI', 'EI', 'SS']]
# ['025597', 'GIANTS OF JAZZ', 'AAAS', '252S', '2019 Spring Term', 'None', 'MW 4:40PM - 5:55PM', 'Biddle 101', 'John V Brown Jr.', ['S', 'ALP', 'CCI']]
# ['018286', 'RACIAL/ETH MINORITIES AMER POL', 'AAAS', '257', '2014 Spring Term', 'None', 'WF 10:05AM - 11:20AM', 'Gross Hall 105', 'Taneisha Means', ['CCI', 'SS']]
# ['018286', 'RACIAL/ETH MINORITIES AMER POL', 'AAAS', '257', '2014 Fall Term', 'None', 'TuTh 4:40PM - 5:55PM', 'Sociology Psychology 126', 'Ashley Jardina', ['CCI', 'SS']]
# ['018286', 'RACIAL/ETH MINORITIES AMER POL', 'AAAS', '257', '2017 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Trent Hall 039A', 'Ashley Jardina', ['CCI', 'SS']]
# ['018286', 'RACIAL/ETH MINORITIES AMER POL', 'AAAS', '257', '2017 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['CCI', 'SS']]
# ['018286', 'RACIAL/ETH MINORITIES AMER POL', 'AAAS', '257', '2018 Fall Term', 'None', 'WF 11:45AM - 1:00PM', 'Carr 114', 'Ashley Jardina', ['CCI', 'SS']]
# ['014317', 'RACIAL/ETH MINORITIES AMER POL', 'AAAS', '257D', '2012 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['CCI', 'SS']]
# ['017291', 'US HEALTH DISPARITIES', 'AAAS', '260', '2013 Spring Term', 'None', 'TuTh 11:45AM - 1:00PM', 'Sanford 03', 'Sherman A James', ['CCI', 'SS', 'R']]
# ['019367', 'RACE, GENOMICS, AND SOCIETY', 'AAAS', '261', '2015 Fall Term', 'None', 'MW 11:45AM - 1:00PM', 'Westbrook 0014', 'Charmaine D Royal', ['EI', 'NS', 'SS', 'STS']]
# ['021218', 'BLACK EUROPE', 'AAAS', '263', '2015 Fall Term', 'None', 'TuTh 11:45AM - 1:00PM', 'Carr 135', 'Laurie McIntosh', ['CCI', 'CZ', 'EI', 'SS']]
# ['025599', 'BLACK EUROPE', 'AAAS', '263S', '2019 Spring Term', 'None', 'M 3:05PM - 5:35PM', 'West Duke 08A', 'Laurie McIntosh', ['S', 'CCI', 'CZ', 'EI', 'SS']]
# ['025598', 'LATIN AM WARS OF INDEPENDENCE', 'AAAS', '264', '2019 Spring Term', 'None', 'WF 10:05AM - 11:20AM', 'Carr 240', 'John D French', ['CCI', 'CZ', 'SS']]
# ['009281', 'BLACK GODS AND KINGS', 'AAAS', '269', '2016 Fall Term', 'None', 'W 3:05PM - 5:35PM', 'Friedl Bldg 240', 'James Lorand Matory', ['CCI', 'CZ', 'EI', 'SS']]
# ['018837', 'RELIGION IN BLACK AMERICA', 'AAAS', '270S', '2018 Spring Term', 'None', 'WF 3:05PM - 4:20PM', 'LSRC B102', 'Melvin K.H. Peters', ['S', 'CCI', 'CZ']]
# ['019184', 'HUMANITARIANISM IN AFRICA', 'AAAS', '271', '2014 Spring Term', 'None', 'MW 10:05AM - 11:20AM', 'Crowell Building 107', 'Bruce S Hall', ['CCI', 'CZ', 'EI']]
# ['019184', 'HUMANITARIANISM IN AFRICA', 'AAAS', '271', '2014 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['CCI', 'CZ', 'EI']]
# ['019184', 'HUMANITARIANISM IN AFRICA', 'AAAS', '271', '2015 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['CCI', 'CZ', 'EI']]
# ['019184', 'HUMANITARIANISM IN AFRICA', 'AAAS', '271', '2016 Fall Term', 'None', 'TuTh 11:45AM - 1:00PM', 'Languages 109', 'Bruce S Hall', ['CCI', 'CZ', 'EI']]
# ['005616', 'ISLAM IN THE AMERICAS', 'AAAS', '274S', '2015 Spring Term', 'None', 'MW 3:05PM - 4:20PM', 'Social Sciences 107', 'Mona F Hassan', ['S', 'CCI', 'CZ', 'SS', 'W']]
# ['005616', 'ISLAM IN THE AMERICAS', 'AAAS', '274S', '2016 Fall Term', 'None', 'MW 1:25PM - 2:40PM', 'Perkins LINK 060 (Classroom 1)', 'Mona F Hassan', ['S', 'CCI', 'CZ', 'SS', 'W']]
# ['018854', 'RELIGION AND RACE', 'AAAS', '276', '2017 Spring Term', 'None', 'M 1:25PM - 3:55PM', 'Gray 220', 'Melvin K.H. Peters', ['CCI', 'CZ', 'SS']]
# ['018855', 'RELIGION AND RACE', 'AAAS', '276S', '2013 Fall Term', 'None', 'MW 3:05PM - 4:20PM', 'Allen 306', 'Melvin K.H. Peters', ['S', 'CCI', 'CZ', 'SS']]
# ['018855', 'RELIGION AND RACE', 'AAAS', '276S', '2015 Spring Term', 'None', 'MW 3:05PM - 4:20PM', 'Old Chemistry 201', 'Melvin K.H. Peters', ['S', 'CCI', 'CZ', 'SS']]
# ['018855', 'RELIGION AND RACE', 'AAAS', '276S', '2019 Spring Term', 'None', 'MW 3:05PM - 4:20PM', 'Gray 094', 'Melvin K.H. Peters', ['S', 'CCI', 'CZ', 'SS']]
# ['022520', 'RACE, ETHNICITY & CITIZENSHIP', 'AAAS', '280', '2014 Spring Term', 'None', 'TuTh 4:40PM - 5:55PM', 'Allen 103', 'Jean M Beaman', ['CCI', 'SS']]
# ['025653', 'NIGERIA: A MODERN HISTORY', 'AAAS', '285S', '2019 Spring Term', 'None', 'W 3:05PM - 5:35PM', 'Friedl Bldg 204', 'Samuel F Daly', ['S', 'CCI', 'CZ']]
# ['016730', 'SPECIAL TOPCS', 'AAAS', '290', '2015 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['']]
# ['016730', 'SPECIAL TOPCS', 'AAAS', '290', '2016 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['']]
# ['016730', 'SPECIAL TOPCS', 'AAAS', '290', '2016 Fall Term', 'None', 'Th 10:05AM - 12:35PM', 'Sociology Psychology 127', 'Kerry L Haynie, \\n\\nRalph Bruce Lawrence', ['CCI', 'CZ', 'SS']]
# ['016730', 'SPECIAL TOPCS', 'AAAS', '290', '2017 Spring Term', 'None', 'MW 3:05PM - 4:20PM', 'West Duke 08A', 'Martin Paul Smith', ['CCI', 'EI', 'SS']]
# ['016730', 'SPECIAL TOPCS', 'AAAS', '290', '2017 Fall Term', 'None', 'M 10:05AM - 12:35PM', 'Gross Hall 105', 'Kerry L Haynie, \\n\\nRalph Bruce Lawrence', ['CCI', 'CZ', 'SS']]
# ['016730', 'SPECIAL TOPCS', 'AAAS', '290', '2018 Fall Term', 'None', 'M 10:05AM - 12:35PM', 'Physics 227', 'Kerry L Haynie, \\n\\nRalph Bruce Lawrence', ['CCI', 'CZ', 'SS']]
# ['000078', 'DUKE-ADM ST ABR (ADV TOP)', 'AAAS', '290A', '2014 Fall Term', 'None', 'TBA', 'TBA', 'Departmental Staff', ['']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2012 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['S', 'CCI', 'SS']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2013 Spring Term', 'None', 'WF 10:05AM - 11:20AM', 'Languages 207', 'Lindah Mhando', ['S', 'CCI', 'SS']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2013 Fall Term', 'None', 'TuTh 4:40PM - 5:55PM', 'Old Chemistry 116', 'Layla D Brown-Vincent', ['S', 'CCI', 'SS']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2014 Spring Term', 'None', 'MW 1:25PM - 2:40PM', 'Friedl Bldg 240', 'Cynthia R. Greenlee', ['S', 'ALP', 'CCI', 'CZ', 'EI', 'SS', 'R']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2014 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['S']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2015 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['S']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2015 Fall Term', 'None', 'Th 8:45AM - 11:15AM', 'Gross Hall 104', 'Kerry L Haynie, \\n\\nRalph Bruce Lawrence', ['S', 'CCI', 'CZ', 'SS']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2016 Spring Term', 'None', 'MW 10:05AM - 11:20AM', 'Perkins LINK 070 (Seminar 4)', 'Mark A Neal', ['S', 'ALP', 'CCI']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2016 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['S']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2017 Spring Term', 'None', 'MW 4:40PM - 5:55PM', 'Biddle 101', 'John V Brown Jr.', ['S', 'ALP', 'CCI', 'CZ']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2017 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['S']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2018 Fall Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Biddle 086', 'Louise Meintjes', ['S', 'ALP', 'CCI', 'EI', 'SS']]
# ['016731', 'SPECIAL TOPICS', 'AAAS', '290S', '2019 Spring Term', 'None', 'F 1:25PM - 3:55PM', 'West Duke 212', 'Kisha N Daniels', ['S', 'ALP', 'CCI', 'EI']]
# ['024465', 'BLACK MUSLIMS', 'AAAS', '295S', '2017 Spring Term', 'None', 'W 1:25PM - 3:55PM', 'Franklin Center 230', 'Ellen McLarney', ['S', 'CCI', 'CZ']]
# ['023660', 'GEOPOLITICS AND CULTURE', 'AMES', '208S', '2017 Fall Term', 'None', 'MW 8:30AM - 9:45AM', 'White 106', 'Shai Ginsburg', ['S', 'ALP', 'CCI', 'CZ']]
# ['023660', 'GEOPOLITICS AND CULTURE', 'AMES', '208S', '2018 Fall Term', 'None', 'W 1:40PM - 4:10PM', 'Franklin Center 028', 'Erdag M Goknar', ['S', 'ALP', 'CCI', 'CZ']]
# ['017077', 'MELODRAMA EAST AND WEST', 'AMES', '211', '2016 Spring Term', 'None', 'W 1:40PM - 4:10PM', 'West Duke 08A', 'Guo-Juin Hong', ['ALP', 'CCI']]
# ['017077', 'MELODRAMA EAST AND WEST', 'AMES', '211', '2019 Spring Term', 'None', 'Th 12:00PM - 2:30PM', 'Carr 136', 'Ning Zhang', ['ALP', 'CCI']]
# ['001955', 'MIDDLE EAST: FACEBOOK TO FILM', 'AMES', '215S', '2014 Spring Term', 'None', 'Tu 3:05PM - 5:35PM', 'Friedl Bldg 204', 'Rebecca Stein', ['S', 'CCI', 'CZ', 'SS']]
# ['001955', 'MIDDLE EAST: FACEBOOK TO FILM', 'AMES', '215S', '2019 Spring Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Friedl Bldg 204', 'Rebecca Stein', ['S', 'CCI', 'CZ', 'SS']]
# ['023169', 'JEWS AND MUSLIMS', 'AMES', '216', '2015 Spring Term', 'None', 'TuTh 10:05AM - 11:20AM', 'Languages 312', 'Oded Zinger', ['CCI', 'CZ', 'EI']]
# ['023169', 'JEWS AND MUSLIMS', 'AMES', '216', '2016 Spring Term', 'None', 'MW 10:05AM - 11:20AM', 'Social Sciences 109', 'Oded Zinger', ['CCI', 'CZ', 'EI']]
# ['024983', 'ASTROLOGY AND RELIGION', 'AMES', '217', '2018 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['CCI', 'CZ']]
# ['023843', 'THE MIDDLE EAST THROUGH FILM', 'AMES', '218', '2016 Spring Term', 'None', 'W 6:15PM - 9:15PM', 'Carr 103', 'Anna Kipervaser', ['ALP', 'CCI', 'CZ', 'EI']]
# ['023843', 'THE MIDDLE EAST THROUGH FILM', 'AMES', '218', '2017 Spring Term', 'None', 'W 6:15PM - 9:15PM', 'Carr 103', 'Anna Kipervaser', ['ALP', 'CCI', 'CZ', 'EI']]
# ['023843', 'THE MIDDLE EAST THROUGH FILM', 'AMES', '218', '2018 Spring Term', 'None', 'W 6:15PM - 9:15PM', 'Carr 103', 'Anna Kipervaser', ['ALP', 'CCI', 'CZ', 'EI']]
# ['023843', 'THE MIDDLE EAST THROUGH FILM', 'AMES', '218', '2019 Spring Term', 'None', 'W 6:15PM - 9:15PM', 'Carr 103', 'Anna Kipervaser', ['ALP', 'CCI', 'CZ', 'EI']]
# ['019072', 'FROM AL-QAEDA TO ISIS', 'AMES', '220S', '2012 Fall Term', 'None', 'Th 1:40PM - 4:10PM', 'Perkins LINK (071) classroom 5', 'Mbaye B Lo', ['S', 'CCI', 'CZ', 'EI', 'SS', 'W']]
Fall Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Environment Hall 2102', 'Erika S Weinthal, \\n\\nRebecca Stein', ['CCI', 'EI', 'SS']]
# ['014810', 'T\'AI CHI AND CHINESE THOUGHT", \'AMES', '247', '2017 Fall Term', 'None', 'M 4:55PM - 7:25PM', 'Bivins 109', 'David N Need', "'CCI", ['CZ']]
# ['014810', 'T\'AI CHI AND CHINESE THOUGHT", \'AMES', '247', '2018 Fall Term', 'None', 'M 4:55PM - 7:25PM', 'East Duke 209', 'David N Need', "'CCI", ['CZ']]
# ['023929', 'JOURNEYS TO THE INDIGENOUS', 'AMES', '252S', '2016 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Languages 207', 'Satendra Khanna', ['S', 'ALP', 'CCI']]
# ['023929', 'JOURNEYS TO THE INDIGENOUS', 'AMES', '252S', '2018 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Perkins LINK 072 (Classroom 6)', 'Satendra Khanna', ['S', 'ALP', 'CCI']]
# ['016787', 'EPICS OF INDIA', 'AMES', '253S', '2015 Spring Term', 'None', 'W 10:05AM - 12:35PM', 'Westbrook 0014', 'Leela Prasad', ['S', 'ALP', 'CCI', 'CZ']]
# ['016787', 'EPICS OF INDIA', 'AMES', '253S', '2016 Spring Term', 'None', 'Th 10:05AM - 12:35PM', 'Gray 220', 'Leela Prasad', ['S', 'ALP', 'CCI', 'CZ']]
# ['016787', 'EPICS OF INDIA', 'AMES', '253S', '2017 Spring Term', 'None', 'Th 3:05PM - 5:35PM', 'Gray 220', 'Leela Prasad', ['S', 'ALP', 'CCI', 'CZ']]
# ['016787', 'EPICS OF INDIA', 'AMES', '253S', '2018 Spring Term', 'None', 'Tu 10:05AM - 12:35PM', 'Perkins LINK 065 (Classroom 2)', 'Leela Prasad', ['S', 'ALP', 'CCI', 'CZ']]
# ['023878', 'RELIGION & NOVEL IN INDIA', 'AMES', '255', '2016 Spring Term', 'None', 'Tu 3:05PM - 5:35PM', 'Gray 220', 'Leela Prasad', ['ALP', 'CCI', 'CZ', 'EI']]
# ['023878', 'RELIGION & NOVEL IN INDIA', 'AMES', '255', '2019 Spring Term', 'None', 'W 3:05PM - 5:35PM', 'Gray 220', 'Leela Prasad', ['ALP', 'CCI', 'CZ', 'EI']]
# ['015830', 'CONTEMP JAPANESE VIS CULTURE', 'AMES', '262', '2016 Fall Term', 'None', 'MW 3:05PM - 4:20PM', 'Smith Warehouse Bay 9 A290', 'Ryan Holmberg', ['ALP', 'CCI', 'CZ', 'W']]
# ['021954', 'VOICES IN GH: ARABIC TUTORIAL', 'AMES', '270T-1', '2015 Spring Term', 'None', 'W 6:15PM - 7:30PM', 'Sociology Psychology 128', 'Maha Houssami', ['']]
# ['021954', 'VOICES IN GH: ARABIC TUTORIAL', 'AMES', '270T-1', '2016 Spring Term', 'None', 'W 6:15PM - 7:30PM', 'Perkins LINK 079 (Seminar 3)', 'Azeddine Chergui, \\n\\nDeborah S Reisinger', ['']]
# ['021954', 'VOICES IN GH: ARABIC TUTORIAL', 'AMES', '270T-1', '2017 Spring Term', 'None', 'TBA', 'TBA', 'Staff', ['']]
# ['021954', 'VOICES IN GH: ARABIC TUTORIAL', 'AMES', '270T-1', '2018 Spring Term', 'None', 'W 4:55PM - 6:15PM', 'Franklin Center 230', 'Maha Houssami', ['']]
# ['021954', 'VOICES IN GH: ARABIC TUTORIAL', 'AMES', '270T-1', '2019 Spring Term', 'None', 'W 4:55PM - 6:10PM', 'Languages 312', 'Maha Houssami', ['']]
# ['021955', 'VOICES IN GH: HINDI TUTORIAL', 'AMES', '270T-4', '2014 Fall Term', 'None', 'Th 6:15PM - 7:30PM', 'Languages 208', 'Premlata Vaishnava', ['']]
# ['021955', 'VOICES IN GH: HINDI TUTORIAL', 'AMES', '270T-4', '2015 Fall Term', 'None', 'TBA', 'TBA', 'Staff', ['']]
# ['021955', 'VOICES IN GH: HINDI TUTORIAL', 'AMES', '270T-4', '2016 Spring Term', 'None', 'W 4:55PM - 6:10PM', 'Social Sciences 109', 'Deborah S Reisinger, \\n\\nDivya Guru Rajan', ['']]
# ['021956', 'VOICES IN GH:MANDARIN TUTORIAL', 'AMES', '270T-5', '2015 Spring Term', 'None', 'W 4:40PM - 5:55PM', 'Trent Hall 038A', 'Tianshu He', ['']]
# ['021956', 'VOICES IN GH:MANDARIN TUTORIAL', 'AMES', '270T-5', '2016 Spring Term', 'None', 'W 3:05PM - 4:20PM', 'Perkins LINK 087 (Classroom 3)', 'Deborah S Reisinger, \\n\\nTianshu He', ['']]
# ['021956', 'VOICES IN GH:MANDARIN TUTORIAL', 'AMES', '270T-5', '2017 Spring Term', 'None', 'W 4:55PM - 6:10PM', 'Languages 312', 'Deborah S Reisinger, \\n\\nYan Liu', ['']]
# ['021956', 'VOICES IN GH:MANDARIN TUTORIAL', 'AMES', '270T-5', '2018 Spring Term', 'None', 'W 4:55PM - 6:10PM', 'Trent Hall 039', 'Yan Liu', ['']]
# ['021956', 'VOICES IN GH:MANDARIN TUTORIAL', 'AMES', '270T-5', '2019 Spring Term', 'None', 'W 4:55PM - 6:10PM', 'Old Chemistry 003', 'Yan Liu', ['']]
# ['021813', 'BUDDHISM AND SEXUALITY', 'AMES', '286S', '2013 Spring Term', 'None', 'Th 1:25PM - 3:55PM', 'Social Sciences 109', 'Hwansoo Kim', ['S', 'CCI', 'CZ', 'EI']]
# ['021813', 'BUDDHISM AND SEXUALITY', 'AMES', '286S', '2014 Spring Term', 'None', 'M 1:25PM - 3:55PM', 'Gray 319', 'Hwansoo Kim', ['S', 'CCI', 'CZ', 'EI']]
# ['021813', 'BUDDHISM AND SEXUALITY', 'AMES', '286S', '2015 Fall Term', 'None', 'M 12:00PM - 2:35PM', 'Gray 319', 'Hwansoo Kim', ['S', 'CCI', 'CZ', 'EI']]
# ['021813', 'BUDDHISM AND SEXUALITY', 'AMES', '286', '2017 Spring Term', 'None', 'Th 3:05PM - 5:35PM', 'Social Sciences 311', 'Hwansoo Kim', ['CCI', 'CZ', 'EI']]
# ['021813', 'BUDDHISM AND SEXUALITY', 'AMES', '286', '2018 Spring Term', 'None', 'Tu 11:45AM - 2:15PM', 'Gray 220', 'Hwansoo Kim', ['CCI', 'CZ', 'EI']]
term', 'None', 'TuTh 3:05PM - 4:20PM', 'Trent Hall 038B', 'Satendra Khanna', ['S', 'ALP', 'CCI', 'CZ']]
# ['012958', 'POETIC CINEMA', 'AMES', '311S', '2019 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'Perkins LINK 070 (Seminar 4)', 'Satendra Khanna', ['S', 'ALP', 'CCI', 'CZ']]
# ['023608', 'BUDDHIST MEDITATION', 'AMES', '315', '2015 Fall Term', 'None', 'W 3:05PM - 5:35PM', 'LSRC A247', 'Richard Jaffe', ['CCI', 'CZ', 'EI']]
# ['023608', 'BUDDHIST MEDITATION', 'AMES', '315', '2017 Fall Term', 'None', 'Tu 3:05PM - 5:35PM', 'Gray 220', 'Richard Jaffe', ['CCI', 'CZ', 'EI']]
# ['023287', 'BREAKDANCERS, VOCALOIDS & GAME', 'AMES', '316S', '2015 Spring Term', 'None', 'TuTh 10:05AM - 11:20AM', 'Allen 326', 'Dwayne Dixon', ['S', 'CCI', 'CZ', 'SS']]
# ['023287', 'BREAKDANCERS, VOCALOIDS & GAME', 'AMES', '316S', '2015 Fall Term', 'None', 'TuTh 1:25PM - 2:40PM', 'Social Sciences 107', 'Dwayne Dixon', ['S', 'CCI', 'CZ', 'SS']]
# ['023287', 'BREAKDANCERS, VOCALOIDS & GAME', 'AMES', '316S', '2017 Spring Term', 'None', 'TuTh 3:05PM - 4:20PM', 'East Duke 108', 'Dwayne Dixon', ['S', 'CCI', 'CZ', 'SS']]
# ['023545', 'MARTIN LUTHER KING', 'AMES', '317', '2015 Fall Term', 'None', 'Tu 4:55PM - 7:45PM', 'Franklin Center 028', 'Omid Safi', ['CCI', 'CZ', 'EI', 'SS', 'R']]
# 893

# %%
ls
# Out:
# Classes Progress.rtf     course.csv               takes_course.csv
# Compsci 316 Final.ipynb  in_study_group.csv       tas_course.csv
# Major Likelyhood.csv     professor.csv            teaches_course.csv
# Netids.csv               rates_course.csv         tutor.csv
# Teachers Raw.csv         student.csv              tutors_for.csv
# all_classes.csv          study_group.csv

# %%
# all_classes = []
# ##this is the section where I actually do stuff. I had to put a couple of brakes or else it would take hours to run
# for i in range(len(complete_course_list)):
#     print complete_course_list[i]
# #     print i
#     ids_and_numbers = get_ids_and_numbers(complete_course_list[i])
#     if ids_and_numbers == "skip":
#         continue
#     for j in range(len(ids_and_numbers)):
# #         if j == 5: #brake one. It only allows there to be 5 types of ids_and_numbers per department
# #             break
#         for k in range(len(all_terms)): #brake two. It only includes the most recent 3 or 4 terms I forget
#             answer = make_course(ids_and_numbers[j][0],ids_and_numbers[j][1],all_terms[k])
#             if answer != []:
#                 all_classes.append(answer)
# #                 print answer
# ##My idea is to get a basic list for the second check in and then take off the brakes when we have more time. This would
# ##take hours if not days to run if no brakes were there and enough functionality is there even with brakes
# Out:
# ['AAAS', 'African and African American S']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-157-ec5577f354a0> in <module>()
#      11 #             break
#      12         for k in range(len(all_terms)): #brake two. It only includes the most recent 3 or 4 terms I forget
# ---> 13             answer = make_course(ids_and_numbers[j][0],ids_and_numbers[j][1],all_terms[k])
#      14             if answer != []:
#      15                 all_classes.append(answer)
#
# <ipython-input-150-8bd1310993f5> in make_course(course_id, course_offer_number, time_period)
#      11     url_full = url_section0 + url_section1 + url_section2 + url_section3 + url_section4 + url_section5 + url_section6 + token
#      12 #     print url_full
# ---> 13     data = rq.get(url_full).json()
#      14 #   if data["ssr_get_course_offering_resp"]["course_offering_result"]["ssr_crs_gen_msg"] == "***  This course has not been scheduled.  ***":
#      15 #         url = url_base
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378         try:
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     256     def recv(self, *args, **kwargs):
#     257         try:
# --> 258             data = self.connection.recv(*args, **kwargs)
#     259         except OpenSSL.SSL.SysCallError as e:
#     260             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/OpenSSL/SSL.pyc in recv(self, bufsiz, flags)
#    1591             result = _lib.SSL_peek(self._ssl, buf, bufsiz)
#    1592         else:
# -> 1593             result = _lib.SSL_read(self._ssl, buf, bufsiz)
#    1594         self._raise_ssl_error(self._ssl, result)
#    1595         return _ffi.buffer(buf, result)[:]
#
# KeyboardInterrupt:

# %%
with open('all_classes.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for course in all_classes:
        prereqs = course[5].replace(",",":")
        name = course[1].replace(","," ")
        teacher = course[8].replace(",",":").replace("\n","")
        tags = ":".join(course[9])
        spamwriter.writerow([str(course[0]),name,course[2],course[3],course[4],prereqs,course[6],course[7], teacher, tags])
#         spamwriter.writerow([course[0],course[1],course[2],course[3],course[4],course[5],course[6],course[7],course[8]])

# %%
teaches_course = [] ##final table
courses = [] ##final table
for course in all_classes: ## all information can be made from 
    teaches_course.append([course[0],course[4],"1",course[-2],course[2]])
    courses.append([course[0],course[2],course[3]," ".join(course[-1]),course[5],course[6],course[4]])

# for course in courses:
#     print course

# %%
## in this I get all possible combinations of letters and numbers that make up netids
alpha = "abcdefghijklmnoprstuvwyz" ##I did not include q or x because none of the thousands of netids i saw had those
                                   ##letters. That is why it is in range(24) and not 26
numer = "0123456789"

three_alpha = [] ##some netids have 3 letters and 2 numbers
for i in range(24):
    for j in range(24):
        for k in range(24):
            for l in range(10):
                for m in range(10):
                    three_alpha.append(alpha[i] + alpha[j] + alpha[k] + numer[l] + numer[m])
     
two_alpha = [] ##some netids have 2 letters and 3 numbers
for i in range(24):
    for j in range(24):
        for k in range(10):
            for l in range(10):
                for m in range(10):
                    two_alpha.append(alpha[i] + alpha[j] + numer[k] + numer[l] + numer[m])
                    
three_alpha.extend(two_alpha) ##combining two types of netids
netids = three_alpha

# %%
start_pos = netids.index("bam76") + 1
print start_pos
# Out:
# 58877

# %%
import csv ##had to use csv because if I went through all of the netids at once it would actually take over a day. I ran
           ##it overnight and it still didn't finish. I ran for a while and saved all of the a's to a CSV. There were a 
           ##lot of them and in my oppinion enough to get some preliminary data
netids2 = []
with open('Netids.csv', 'rb') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        netids2.append(row[0])
# print netids2

# %%
students = []
professors = []
url_section0 = "https://streamer.oit.duke.edu/ldap/people/netid/"
url_section2 = "?access_token="
print len(netids)
for netid in netids[start_pos:]:
    data = rq.get(url_section0 + netid + url_section2 + token).json()
    if data == []: ##netid does not exist
        continue
    if "emails" not in data[0].keys(): ##weird edge case
        continue
    if "duke" not in data[0]["emails"][0]: ##netid is for another university that is not duke (I found a few)
        continue
    if data[0]["primary_affiliation"] not in ["Faculty","Student"]: ##only care about teachers and students. Not staff
        continue
    name = data[0]["display_name"]
    if data[0]["primary_affiliation"] == "Student":
        students.append([netid,name])
        print netid
    if data[0]["primary_affiliation"] == "Faculty":
        if str(data[0]["department"]) == "Fin Aid & Non-Perm Positions": ##these people weren't actual teachers
            continue
        print netid
        professors.append([name,netid,data[0]["emails"][0],data[0]["phones"][0],data[0]["department"]]) ##final table
        ##I decided to add in phone number because it was really easy
print "Done!"
# Out:
# 1958400
# bae13
# baf24
# baf33
# bag21
# bag40
# bag41
# bah34
# bah37
# bak36
# bak45
# bal31
# bal36
# bal44
# bal46
# bam48
# bam60
# bam74
# bam76
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-7ad859af713e> in <module>()
#       5 print len(netids)
#       6 for netid in netids[start_pos:]:
# ----> 7     data = rq.get(url_section0 + netid + url_section2 + token).json()
#       8     if data == []: ##netid does not exist
#       9         continue
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378         try:
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     256     def recv(self, *args, **kwargs):
#     257         try:
# --> 258             data = self.connection.recv(*args, **kwargs)
#     259         except OpenSSL.SSL.SysCallError as e:
#     260             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/michaelhorenstein/anaconda2/lib/python2.7/site-packages/OpenSSL/SSL.pyc in recv(self, bufsiz, flags)
#    1591             result = _lib.SSL_peek(self._ssl, buf, bufsiz)
#    1592         else:
# -> 1593             result = _lib.SSL_read(self._ssl, buf, bufsiz)
#    1594         self._raise_ssl_error(self._ssl, result)
#    1595         return _ffi.buffer(buf, result)[:]
#
# KeyboardInterrupt:

# %%
import random
## to make up what people's majors were I wanted to be slighly realistic. I found online this website,
#"https://www.collegeraptor.com/colleges/majors/Duke-University-NC--198419". This had the major statistics for 2016 and
## i figured they were around the same. I made a list that was made up of majors weighted based on how common they were
## in 2016 below. I then assigned students majors by randomly picking one from the list
likelyhood_majors = []

with open('Major Likelyhood.csv', 'rb') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        major = row[0].split(",")[0]
        quantity = row[0].split(",")[1]
        likelyhood_majors.extend([major for x in range(int(quantity))])
top_random_number = len(likelyhood_majors)
random.shuffle(likelyhood_majors)
random.shuffle(students)
for i in range(len(students)):
    students[i].append(likelyhood_majors[random.randrange(top_random_number)])
    if i < (len(students)/3): ##I ended up giving some double majors. This will be less than 1/3 because i eventually
                              ##delete double majors where the second was the same as the first
        students[i].append(likelyhood_majors[random.randrange(top_random_number)])
    else:
        students[i].append("")
        
random.shuffle(students)

# %%
grad_years = [2019,2020,2021,2022]
for student in students: ##I said that around 1/4 were in each grade but not perfect
    student.append(grad_years[random.randrange(4)])
# for student in students:
#     print student

# %%
for student in students: ##I gave people GPAs that ranged from 2.5/4. The distribution is uniform but I know in real
                         ##life it isn't
    student.append(float(random.randrange(250,400))/100)
# for student in students:
#     print student

# %%
# #https://trinity.duke.edu/directory/people/a
# cleaner = []
# with open('Teachers Raw.csv', 'rb') as csvfile:
#     spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
#     for line in spamreader:
#         stringline = " ".join(line)
#         if stringline != "":
#             cleaner.append(stringline)
# # print cleaner
# cleaner.extend(["filler","filler","Contact"])
# professors = []
# name = ""
# phone = ""
# email = ""
# departments = ""
# i = 0
# while i < len(cleaner) - 3:
#     if cleaner[i+2] == "Contact" and cleaner[i] != "filler":
#         name = cleaner[i][1:-1]
# #         print name
# #     if cleaner[i+2] == "Departments":
# #         phone = cleaner[i]
# # #         print phone
#     if cleaner[i+1] == "Departments":
#         if "(" not in cleaner[i]:
#             email = cleaner[i]
#         else:
#             email = ""
        
# #         print email
#     if cleaner[i] == "Departments":
#         j = 1
#         departments = []
#         while cleaner[i + j + 2] != "Contact":
# #             print cleaner[i + j + 2]
#             if not cleaner[i+j][0].isalpha():
#                 departments.append(cleaner[i+j][1:-1])
#             else:
#                 departments.append(cleaner[i+j])
#             j = j + 1
#         professors.append([name,email, ":".join(departments)])
#     i = i + 1
    
# print professors[random.randrange(2200)][0]

# %%
for student in students: ##I decided that a student's favorite professor could be anybody not just people they've had as
                         ##a teacher
    student.append(professors[random.randrange(len(professors))][0])
    if student[2] == student[3]:
        student[3] = "" ##getting rid of redundant double majors

# %%
course_dict = {} ##keys are the department, values are the courses within the department. This is useful later
for course in courses:
#     print course
    
    if course[1] in course_dict:
        course_dict[course[1]].append(course)
    else:
        course_dict[course[1]] = []
        course_dict[course[1]].append(course)
#         print course_dict[course[1]]
# print course_dict["AAAS"]

# %%
def classes_taken_per_student(): ##assigning classes to students. I know its not by any means perfect, but it is pretty
                                 ##good for what it is and it does not have to be perfect
    all_classes_taken = []
    for student in students:
        classes_taken = []
        num_classes = 8*(2023 - student[-3]) - 4 ##assume that everyone takes 4 classes a semester
        major1 = student[2]
        major2 = student[3]
        
        num_classes_in_major = 0
        if major1 in course_dict.keys():
            num_classes_in_major = len(course_dict[major1])
#         print num_classes_in_major
        major_classes = min(num_classes/3,num_classes_in_major) ##major accounts for 1/3 of classes or as many that
        if major1 in course_dict.keys():                        ##exist in that department. Minimum.
            i = 0
            random.shuffle(course_dict[major1])
            while (len(classes_taken) < major_classes) and (i < len(course_dict[major1])):
                class_to_add = course_dict[major1][i]
#             print class_to_add[0]
                class_id = class_to_add[0]
                all_current_classid = [x[1] for x in classes_taken]
#                 print str(class_id), all_current_classid
                if str(class_id) not in all_current_classid: ##don't add the same class twice
                    classes_taken.append([student[0],class_to_add[0],class_to_add[-1],random.randrange(75,100)])
#                     print classes_taken
                i = i + 1
#                 print i

        num_classes_in_major = 0
        if major2 != "" and major2 in course_dict.keys(): ##repeat same process but this time for major2
            num_classes_in_major = len(course_dict[major2])
#         print num_classes_in_major
        major_classes = min(num_classes/3,num_classes_in_major)
        if major2 in course_dict.keys():
            i = 0
            random.shuffle(course_dict[major2])
            while (len(classes_taken) < major_classes) and (i < len(course_dict[major2])):
                class_to_add = course_dict[major2][i]
#             print class_to_add[0]
                class_id = class_to_add[0]
                all_current_classid = [x[1] for x in classes_taken]
#                 print str(class_id), all_current_classid
                if str(class_id) not in all_current_classid:
                    classes_taken.append([student[0],class_to_add[0],class_to_add[-1],random.randrange(75,100)])
#                     print classes_taken
                i = i + 1
#                 print i  

        classes_left = num_classes - len(classes_taken) ##number of classes not from major
#         print classes_left
        num_extra = 0
        while num_extra < classes_left:
            class_to_add = courses[random.randrange(6,len(courses))]
            class_id = class_to_add[0]
            all_current_classid = [x[1] for x in classes_taken]
            if str(class_id) not in all_current_classid:
                ##add random classes you don't already have until you get all of your classes you need
                classes_taken.append([student[0],class_to_add[0],class_to_add[-1],random.randrange(75,100)])
                num_extra = num_extra + 1

        all_classes_taken.append(classes_taken)
    
    return all_classes_taken

takes_course = classes_taken_per_student()

# %%
# for personsclasses in takes_course:
#     print personsclasses
#     print

# %%
for student in students: ##gets favorite class. I assumed here that students only have one and have to had taken the 
    for personsclasses in takes_course: ##class
        if personsclasses[0][0] == student[0]:
            student.append(personsclasses[0][1])
            break
#     print student

# %%
all_takes_classes = []
for personsclasses in takes_course:
    all_takes_classes.extend(personsclasses) ##change format to make it useful for later

# %%
random.shuffle(all_takes_classes)
course_ratings = [] ##final table
for i in range(len(all_takes_classes)/20): ##assume that 1/20 of people rate the class
    netid = all_takes_classes[i*20][0]
    course = all_takes_classes[i*20][1]
    time_frame = all_takes_classes[i*20][-2]
    quality_of_course = random.randrange(100)/10.0 ##I did random ratings in the 4 categories. Could change if needed
    quality_of_instruction = random.randrange(100)/10.0
    difficulty = random.randrange(100)/10.0
    workload = random.randrange(100)/10.0
    course_ratings.append([netid,course,time_frame,quality_of_course,quality_of_instruction,difficulty,workload])

# for rating in course_ratings:
#     print rating

# %%
tutors_for = [] ##final table
for i in range(len(all_takes_classes)):
    if all_takes_classes[i][-1] > 98: ##assume only people with 99 in class can tutor
        stopper = random.randrange(10) ##1/10 of these people actually decide to tutor
        if stopper == 5:
            tutors_for.append([all_takes_classes[i][0],all_takes_classes[i][1]])
# for person in tutors_for:
#     print person

# %%
tutor_net_ids = [x[0] for x in tutors_for]
possible_days_availible = ["M","T","W","TH","F"] ##people can work any of the days. I did a weird method to pick specifics but it works
tutor = [] ##final table
for netid in set(tutor_net_ids):
#     print netid
    pay = random.randrange(10,20) ##people get payed anywhere between 10 and 20 an hour
    days_availible = []
    for i in range(5):
        if random.randrange(2) == 1:
            days_availible.append(possible_days_availible[i])
#     print days_availible
    if len(days_availible) == 0:
        days_availible = possible_days_availible[random.randrange(5)]
    days_availible = ":".join(days_availible)
#     print days_availible
    tutor.append([netid,pay,days_availible])
# print tutor

# %%
tas_for = [] ##final table

terms_offered = ["2012 Fall Term", "2013 Spring Term","2013 Fall Term","2014 Spring Term","2014 Fall Term","2015 Spring Term","2015 Fall Term","2016 Spring Term","2016 Fall Term","2017 Spring Term","2017 Fall Term","2018 Spring Term","2018 Fall Term","2019 Spring Term"]

for i in range(len(all_takes_classes)):
    if all_takes_classes[i][-1] > 98: ##only people with 99 ta
        stopper = random.randrange(20) 
        if stopper == 10: ## 1/20 people TA with 99s
            netid = all_takes_classes[i][0]
            course_number = all_takes_classes[i][1]
            class_time_frame = all_takes_classes[i][-2]
            semester_ta = ""
            if class_time_frame != "2019 Spring Term": ##said that they TA the semester after they took the class and don't 
#                 print terms_offered[terms_offered.index(class_time_frame) + 1]
                
                semester_ta = terms_offered[terms_offered.index(class_time_frame) + 1] ##TA if are in spring 2019
                tas_for.append([netid,course_number,semester_ta])
# for person in tas_for:
#     print person

# %%
dict_courses = {}
for course in all_takes_classes: ##keys = course and term, values = people in class
    unique_course = ":".join(course[1:3])
    if unique_course not in dict_courses.keys():
        dict_courses[unique_course] = [course[0]]
    else:
        dict_courses[unique_course].append(course[0])

study_groups = [] ##final table
in_study_group = [] ##final table
study_group_id = 0

all_unique_courses = dict_courses.keys()
random.shuffle(all_unique_courses)
for i in range(len(all_unique_courses)/2): ##1/2 of classes have study groups
    specific_course = all_unique_courses[i]
    amount_of_groups = len(dict_courses[specific_course])/10 ## average of 1 study group for 10 people
    for j in range(amount_of_groups):
        size_of_group = random.randrange(3,8) ##groups range from 3-8 people
        study_groups.append([study_group_id,specific_course.split(":")[0],specific_course.split(":")[1]])
        random.shuffle(dict_courses[specific_course])
        for k in range(size_of_group):
            in_study_group.append([study_group_id,dict_courses[specific_course][k]])
        study_group_id += 1

# for group in in_study_group:
#     print group
    
# for group in study_groups:
#     print group

# %%
final_student = []
final_student.append(["netid","name","major1","major2","grad_year","GPA","fav_teacher","fav_class"])
for student in students:
    netid = student[0]
    name = student[1].encode('utf-8')
    major1 = student[2]
    major2 = student[3]
    grad_year = student[4]
    GPA = student[5]
    fav_teacher = student[6].encode('utf-8').replace("|","").replace(","," ")
    fav_class = student[7]
    final_student.append([netid,name,major1,major2,grad_year,GPA,fav_teacher,fav_class])

with open('student.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_student:
        spamwriter.writerow(row)

# %%
final_course = []
final_course.append(["number","department","level","tags","prereqs","meeting_times"])
for course in courses:
    number = course[0]
    department = course[1]
    level = course[2].strip()
    tags = course[3]
    prereqs = course[4].replace("|","").replace(","," ")
    meeting_times = course[5]
    final_course.append([number,department,level,tags,prereqs,meeting_times])

with open('course.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_course:
        spamwriter.writerow(row)

# %%
final_takes_course = []
final_takes_course.append(["netid","number","term","grade"])

for action in all_takes_classes:
    netid = action[0]
    number = action[1]
    term = action[2]
    grade = action[3]
    final_takes_course.append([netid,number,term,grade])

with open('takes_course.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_takes_course:
        spamwriter.writerow(row)

# %%
final_rates_course = []
final_rates_course.append(["netid","number","term","quality_course","quality_instructor","difficulty","workload"])

for rating in course_ratings:
    netid = rating[0]
    number = rating[1]
    term = rating[2]
    quality_course = rating[3]
    quality_instructor = rating[4]
    difficulty = rating[5]
    workload = rating[6]
    final_rates_course.append([netid,number,term,quality_course,quality_instructor,difficulty,workload])

with open('rates_course.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_rates_course:
        spamwriter.writerow(row)

# %%
final_professor = []
final_professor.append(["name","netid","email","phone","department"])

for professor in professors:
    name = professor[0].encode('utf-8').replace("|","").replace(","," ")
    netid = professor[1]
    email = professor[2]
    phone = professor[3].encode('utf-8')
    department = professor[4].encode('utf-8').replace("|","").replace(","," ")
    final_professor.append([name,netid,email,phone,department])

with open('professor.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_professor:
        spamwriter.writerow(row)

# %%
final_teaches_course = []
final_teaches_course.append(["number","term","professor","department"])

for course in teaches_course:
    number = course[0]
    term = course[1]
    professor = course[3].replace("\n","").replace("|","").replace(","," ")
    department = course[4].replace("|","").replace(","," ")
    final_teaches_course.append([number,term,professor,department])

with open('teaches_course.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_teaches_course:
        spamwriter.writerow(row)

# %%
final_study_group = []
final_study_group.append(["group_id","class_number","term"])

for group in study_groups:
    group_id = group[0]
    class_number = group[1]
    term = group[2]
    final_study_group.append([group_id,class_number,term])

with open('study_group.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_study_group:
        spamwriter.writerow(row)

# %%
final_in_study_group = []
final_in_study_group.append(["group_id","net_id"])


for group in in_study_group:
    group_id = group[0]
    net_id = group[1]
    final_in_study_group.append([group_id,net_id])

with open('in_study_group.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_in_study_group:
        spamwriter.writerow(row)

# %%
final_tutor = []
final_tutor.append(["netid","rate_per_hour","days_availible"])

for t in tutor:
    netid = t[0]
    rate_per_hour = t[1]
    days_availible = t[2].replace("|","").replace(","," ")
    final_tutor.append([netid,rate_per_hour,days_availible])
    
with open('tutor.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_tutor:
        spamwriter.writerow(row)

# %%
final_tutors_for = []
final_tutors_for.append(["net_id","course_number"])

for person in tutors_for:
    net_id = person[0]
    course_number = person[1]
    final_tutors_for.append([net_id,course_number])
    
with open('tutors_for.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_tutors_for:
        spamwriter.writerow(row)

# %%
final_tas_course = []
final_tas_course.append(["netid","number","term"])

for person in tas_for:
    netid = person[0]
    number = person[1]
    term = person[2]
    final_tas_course.append([netid,number,term])

with open('tas_course.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in final_tas_course:
        spamwriter.writerow(row)
